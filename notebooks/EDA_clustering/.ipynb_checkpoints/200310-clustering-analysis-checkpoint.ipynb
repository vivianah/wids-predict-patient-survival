# %% [markdown]
# ## Notebook to Examine clusters created from DBScans and KMeans

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### reading in the labels from the clustering analysis

# %%
c_df = pd.read_csv('labels_clustering.csv')

# %%
c_df.head(4)
# Out:
#    patient_id  DBSCAN_label  KMeans
# 0       25312             0       3
# 1       59342             0       3
# 2       50777            -1       4
# 3       46918            -1       0

# %%
c_df.shape
# Out:
# (91713, 3)

# %%
# %store -r wids

# %%
wids.shape
# Out:
# (91713, 301)

# %%
labeled_df = wids.merge(c_df, on = 'patient_id', how = 'left')
labeled_df.head(2)
# Out:
#    patient_id  encounter_id  hospital_id  hospital_death   age    bmi  \
# 0       25312         66154          118               0  68.0  22.73
# 1       59342        114252           81               0  77.0  27.42
#
#    elective_surgery  ethnicity gender  height  ... spo2_min_change  \
# 0                 0  Caucasian      M   180.3  ...             0.0
# 1                 0  Caucasian      F   160.0  ...             0.0
#
#   sysbp_max_change  sysbp_min_change temp_max_change temp_min_change  \
# 0              0.0              42.0            -0.4             0.3
# 1            -64.0               4.0             0.0             1.2
#
#    wbc_max_change  wbc_min_change        apache_3j_diagnosis_desc  \
# 0             NaN             NaN  Sepsis_of_urinary_tract_origin
# 1           -10.6             0.0              Respiratory_arrest
#
#    DBSCAN_label KMeans
# 0             0      3
# 1             0      3
#
# [2 rows x 304 columns]

# %%
list(labeled_df.columns)
# Out:
# ['patient_id',
#  'encounter_id',
#  'hospital_id',
#  'hospital_death',
#  'age',
#  'bmi',
#  'elective_surgery',
#  'ethnicity',
#  'gender',
#  'height',
#  'hospital_admit_source',
#  'icu_admit_source',
#  'icu_id',
#  'icu_stay_type',
#  'icu_type',
#  'pre_icu_los_days',
#  'readmission_status',
#  'weight',
#  'albumin_apache',
#  'apache_2_diagnosis',
#  'apache_3j_diagnosis',
#  'apache_post_operative',
#  'arf_apache',
#  'bilirubin_apache',
#  'bun_apache',
#  'creatinine_apache',
#  'gcs_eyes_apache',
#  'gcs_motor_apache',
#  'gcs_unable_apache',
#  'gcs_verbal_apache',
#  'glucose_apache',
#  'heart_rate_apache',
#  'hematocrit_apache',
#  'intubated_apache',
#  'map_apache',
#  'resprate_apache',
#  'sodium_apache',
#  'temp_apache',
#  'urineoutput_apache',
#  'ventilated_apache',
#  'wbc_apache',
#  'd1_diasbp_max',
#  'd1_diasbp_min',
#  'd1_diasbp_noninvasive_max',
#  'd1_diasbp_noninvasive_min',
#  'd1_heartrate_max',
#  'd1_heartrate_min',
#  'd1_mbp_max',
#  'd1_mbp_min',
#  'd1_mbp_noninvasive_max',
#  'd1_mbp_noninvasive_min',
#  'd1_resprate_max',
#  'd1_resprate_min',
#  'd1_spo2_max',
#  'd1_spo2_min',
#  'd1_sysbp_max',
#  'd1_sysbp_min',
#  'd1_sysbp_noninvasive_max',
#  'd1_sysbp_noninvasive_min',
#  'd1_temp_max',
#  'd1_temp_min',
#  'h1_diasbp_max',
#  'h1_diasbp_min',
#  'h1_diasbp_noninvasive_max',
#  'h1_diasbp_noninvasive_min',
#  'h1_heartrate_max',
#  'h1_heartrate_min',
#  'h1_mbp_max',
#  'h1_mbp_min',
#  'h1_mbp_noninvasive_max',
#  'h1_mbp_noninvasive_min',
#  'h1_resprate_max',
#  'h1_resprate_min',
#  'h1_spo2_max',
#  'h1_spo2_min',
#  'h1_sysbp_max',
#  'h1_sysbp_min',
#  'h1_sysbp_noninvasive_max',
#  'h1_sysbp_noninvasive_min',
#  'h1_temp_max',
#  'h1_temp_min',
#  'd1_albumin_max',
#  'd1_albumin_min',
#  'd1_bilirubin_max',
#  'd1_bilirubin_min',
#  'd1_bun_max',
#  'd1_bun_min',
#  'd1_calcium_max',
#  'd1_calcium_min',
#  'd1_creatinine_max',
#  'd1_creatinine_min',
#  'd1_glucose_max',
#  'd1_glucose_min',
#  'd1_hco3_max',
#  'd1_hco3_min',
#  'd1_hemaglobin_max',
#  'd1_hemaglobin_min',
#  'd1_hematocrit_max',
#  'd1_hematocrit_min',
#  'd1_inr_max',
#  'd1_inr_min',
#  'd1_platelets_max',
#  'd1_platelets_min',
#  'd1_potassium_max',
#  'd1_potassium_min',
#  'd1_sodium_max',
#  'd1_sodium_min',
#  'd1_wbc_max',
#  'd1_wbc_min',
#  'h1_glucose_max',
#  'h1_glucose_min',
#  'h1_inr_max',
#  'h1_inr_min',
#  'd1_arterial_pco2_max',
#  'd1_arterial_pco2_min',
#  'd1_arterial_ph_max',
#  'd1_arterial_ph_min',
#  'd1_arterial_po2_max',
#  'd1_arterial_po2_min',
#  'apache_4a_hospital_death_prob',
#  'apache_4a_icu_death_prob',
#  'aids',
#  'cirrhosis',
#  'diabetes_mellitus',
#  'hepatic_failure',
#  'immunosuppression',
#  'leukemia',
#  'lymphoma',
#  'solid_tumor_with_metastasis',
#  'apache_3j_bodysystem',
#  'apache_2_bodysystem',
#  'gcs_score',
#  'creatine_risk',
#  'bilirubin_risk',
#  'glucose_risk',
#  'h1_test_total',
#  'd1_test_total',
#  'missing_test_total',
#  'cc_total',
#  'h1_diasbp_avg',
#  'h1_heartrate_avg',
#  'h1_mbp_avg',
#  'h1_resprate_avg',
#  'h1_spo2_avg',
#  'h1_sysbp_avg',
#  'h1_temp_avg',
#  'h1_albumin_avg',
#  'h1_bilirubin_avg',
#  'h1_bun_avg',
#  'h1_calcium_avg',
#  'h1_creatinine_avg',
#  'h1_glucose_avg',
#  'h1_hco3_avg',
#  'h1_hemaglobin_avg',
#  'h1_hematocrit_avg',
#  'h1_inr_avg',
#  'h1_lactate_avg',
#  'h1_platelets_avg',
#  'h1_potassium_avg',
#  'h1_sodium_avg',
#  'h1_wbc_avg',
#  'h1_arterial_pco2_avg',
#  'h1_arterial_ph_avg',
#  'h1_arterial_po2_avg',
#  'h1_pao2fio2ratio_avg',
#  'h1_diasbp_diff',
#  'h1_heartrate_diff',
#  'h1_mbp_diff',
#  'h1_resprate_diff',
#  'h1_spo2_diff',
#  'h1_sysbp_diff',
#  'h1_temp_diff',
#  'h1_albumin_diff',
#  'h1_bilirubin_diff',
#  'h1_bun_diff',
#  'h1_calcium_diff',
#  'h1_creatinine_diff',
#  'h1_glucose_diff',
#  'h1_hco3_diff',
#  'h1_hemaglobin_diff',
#  'h1_hematocrit_diff',
#  'h1_inr_diff',
#  'h1_lactate_diff',
#  'h1_platelets_diff',
#  'h1_potassium_diff',
#  'h1_sodium_diff',
#  'h1_wbc_diff',
#  'h1_arterial_pco2_diff',
#  'h1_arterial_ph_diff',
#  'h1_arterial_po2_diff',
#  'h1_pao2fio2ratio_diff',
#  'd1_diasbp_diff',
#  'd1_heartrate_diff',
#  'd1_mbp_diff',
#  'd1_resprate_diff',
#  'd1_spo2_diff',
#  'd1_sysbp_diff',
#  'd1_temp_diff',
#  'd1_albumin_diff',
#  'd1_bilirubin_diff',
#  'd1_bun_diff',
#  'd1_calcium_diff',
#  'd1_creatinine_diff',
#  'd1_glucose_diff',
#  'd1_hco3_diff',
#  'd1_hemaglobin_diff',
#  'd1_hematocrit_diff',
#  'd1_inr_diff',
#  'd1_lactate_diff',
#  'd1_platelets_diff',
#  'd1_potassium_diff',
#  'd1_sodium_diff',
#  'd1_wbc_diff',
#  'd1_arterial_pco2_diff',
#  'd1_arterial_ph_diff',
#  'd1_arterial_po2_diff',
#  'd1_pao2fio2ratio_diff',
#  'diasbp_med_diff',
#  'heartrate_med_diff',
#  'mbp_med_diff',
#  'resprate_med_diff',
#  'spo2_med_diff',
#  'sysbp_med_diff',
#  'temp_med_diff',
#  'albumin_med_diff',
#  'bilirubin_med_diff',
#  'bun_med_diff',
#  'calcium_med_diff',
#  'creatinine_med_diff',
#  'glucose_med_diff',
#  'hco3_med_diff',
#  'hemaglobin_med_diff',
#  'hematocrit_med_diff',
#  'inr_med_diff',
#  'lactate_med_diff',
#  'platelets_med_diff',
#  'potassium_med_diff',
#  'sodium_med_diff',
#  'wbc_med_diff',
#  'arterial_pco2_med_diff',
#  'arterial_ph_med_diff',
#  'arterial_po2_med_diff',
#  'pao2fio2ratio_med_diff',
#  'h1_ppv',
#  'd1_ppv',
#  'urine_flag',
#  'wbc_level',
#  'lactate_level',
#  'platelets_level',
#  'albumin_max_change',
#  'albumin_min_change',
#  'arterial_pco2_max_change',
#  'arterial_pco2_min_change',
#  'arterial_ph_max_change',
#  'arterial_ph_min_change',
#  'arterial_po2_max_change',
#  'arterial_po2_min_change',
#  'bilirubin_max_change',
#  'bilirubin_min_change',
#  'bun_max_change',
#  'bun_min_change',
#  'calcium_max_change',
#  'calcium_min_change',
#  'creatinine_max_change',
#  'creatinine_min_change',
#  'diasbp_max_change',
#  'diasbp_min_change',
#  'glucose_max_change',
#  'glucose_min_change',
#  'co3_max_change',
#  'co3_min_change',
#  'eartrate_max_change',
#  'eartrate_min_change',
#  'emaglobin_max_change',
#  'emaglobin_min_change',
#  'ematocrit_max_change',
#  'ematocrit_min_change',
#  'inr_max_change',
#  'inr_min_change',
#  'lactate_max_change',
#  'lactate_min_change',
#  'mbp_max_change',
#  'mbp_min_change',
#  'pao2fio2ratio_max_change',
#  'pao2fio2ratio_min_change',
#  'platelets_max_change',
#  'platelets_min_change',
#  'potassium_max_change',
#  'potassium_min_change',
#  'resprate_max_change',
#  'resprate_min_change',
#  'sodium_max_change',
#  'sodium_min_change',
#  'spo2_max_change',
#  'spo2_min_change',
#  'sysbp_max_change',
#  'sysbp_min_change',
#  'temp_max_change',
#  'temp_min_change',
#  'wbc_max_change',
#  'wbc_min_change',
#  'apache_3j_diagnosis_desc',
#  'DBSCAN_label',
#  'KMeans']

# %% [markdown]
# ### Examining summary statistics of the cluster analysis
# - looked at number of patients, age, median, elective, top gender, top ethnicity, and top diagnosis

# %%
labeled_df.groupby(['DBSCAN_label','hospital_death']).agg(
    num_patients = ('patient_id','nunique'),
    median_age = ('age','median'),
    median_bmi =('bmi','median'),
    top_elective =('elective_surgery',lambda x: x.value_counts(dropna=False).index[0] ),
    top_gender =('gender',lambda x: x.value_counts(dropna=False).index[0]),
    top_ethnicity =('ethnicity',lambda x: x.value_counts(dropna=False).index[0]),
    top_apache_3j_diagnosis_desc =('apache_3j_diagnosis_desc',lambda x: x.value_counts(dropna=False).index[0])
    
)
# Out:
#                              num_patients  median_age  median_bmi  \
# DBSCAN_label hospital_death
# -1           0                      52701        58.0   29.014391
#              1                       5610        69.0   27.270568
#  0           0                      30921        70.0   26.880273
#              1                       2294        74.0   25.995912
#  1           0                         50        55.0   29.743746
#  2           0                         43        87.0   23.215788
#              1                          7        87.0   22.881253
#  3           0                         37        51.0   25.234375
#              1                          2        50.5   24.854656
#  4           0                         46        74.0   31.712448
#              1                          2        74.0   31.980525
#
#                              top_elective top_gender     top_ethnicity  \
# DBSCAN_label hospital_death
# -1           0                          0          M         Caucasian
#              1                          0          M         Caucasian
#  0           0                          0          M         Caucasian
#              1                          0          M         Caucasian
#  1           0                          0          M         Caucasian
#  2           0                          0          M         Caucasian
#              1                          0          F         Caucasian
#  3           0                          0          M         Caucasian
#              1                          0          F  African_American
#  4           0                          0          M         Caucasian
#              1                          0          M     Other_Unknown
#
#                             top_apache_3j_diagnosis_desc
# DBSCAN_label hospital_death
# -1           0                Sepsis__other_than_urinary
#              1                Sepsis__other_than_urinary
#  0           0                Sepsis__other_than_urinary
#              1                Sepsis__other_than_urinary
#  1           0               Acute_myocardial_infarction
#  2           0                  Congestive_heart_failure
#              1                Sepsis__other_than_urinary
#  3           0                  Other_neurologic_disease
#              1                             Drug_overdose
#  4           0                        Rhythm_disturbance
#              1                Sepsis__other_than_urinary

# %% [markdown]
# It looks clustering struggles to find groups of adequate size. However, something interesting to note is that it appears that most of the diagnosis that comes from apache 3j is Sepis_other_than_urinary. This appears to be the most common diagnosis for why people come to the ICU. That means that for both survival and death groups, the most common diagnosis is Sepis_other_than_urinary however there vitals do not look distinctly different. This means that our model struggles to find meaningful distinctions between our variables in the model.

# %%
 t = wids.groupby(['apache_3j_diagnosis_desc'])['hospital_death'].value_counts().reset_index(name = 'counts').sort_values(by = 'counts',ascending = False)

# %%
pd.set_option('display.max_rows', 200)

# %%
t
# Out:
#                               apache_3j_diagnosis_desc  hospital_death  counts
# 176                         Sepsis__other_than_urinary               0    7342
# 0                          Acute_myocardial_infarction               0    4159
# 44                                       Drug_overdose               0    3736
# 170                                 Rhythm_disturbance               0    3720
# 124                       Other_cardiovascular_disease               0    3502
# 182                                             Stroke               0    3440
# 36             Coronary_artery_bypass_grafts__________               0    2911
# 34                            Congestive_heart_failure               0    2637
# 178                     Sepsis_of_urinary_tract_origin               0    2544
# 56                      GI_bleeding___ulcer_laceration               0    2402
# 137                         Other_respiratory_diseases               0    2210
# 40                               Diabetic_ketoacidosis               0    2048
# 10                                 Bacterial_pneumonia               0    2005
# 190                             Valvular_heart_surgery               0    1903
# 28               Chronic_obstructive_pulmonary_disease               0    1740
# 78                        Head_trauma_____multi_trauma               0    1673
# 177                         Sepsis__other_than_urinary               1    1556
# 106                     Multiple_trauma_excluding_head               0    1445
# 188                                    Unstable_angina               0    1427
# 156                                    Renal_disorders               0    1380
# 174                                            Seizure               0    1330
# 32                                                Coma               0    1324
# 54                        GI_bleeding___diverticulosis               0    1205
# 131                          Other_metabolic_disorders               0    1157
# 16                                      Cardiac_arrest               0    1131
# 17                                      Cardiac_arrest               1    1126
# 86                           Intracerebral_haemorrhage               0    1107
# 82                                        Hypertension               0    1056
# 126                      Other_cardiovascular_diseases               0    1021
# 22                              Carotid_endarterectomy               0     990
# 152                                 Pulmonary_embolism               0     978
# 160                                 Respiratory_arrest               0     945
# 133                           Other_neurologic_disease               0     852
# 64                                      GI_obstruction               0     780
# 145                        Peripheral_vascular_disease               0     770
# 62                                         GI_neoplasm               0     718
# 120                                  Other_GI_diseases               0     652
# 14                  CABG_with_valve_repair_replacement               0     652
# 48                                  Epidural_haematoma               0     596
# 46                                        Elective_AAA               0     573
# 38                             Craniotomy_for_neoplasm               0     541
# 99                                      Metabolic_coma               0     494
# 164                        Respiratory_neoplasm___lung               0     466
# 68            GI_perforation_rupture__not_peritonitis_               0     466
# 93                     Laminectomy_Spinal_cord_surgery               0     458
# 24                    Cellulitis_Soft_tissue_infection               0     454
# 97                       Mechanical_airway_obstruction               0     450
# 184                           Subarachnoid_haemorrhage               0     442
# 129                       Other_haematologic_disorders               0     415
# 116                                Orthopaedic_surgery               0     415
# 112                                Neurologic_neoplasm               0     391
# 8                                               Asthma               0     371
# 11                                 Bacterial_pneumonia               1     363
# 139                                       Pancreatitis               0     356
# 183                                             Stroke               1     349
# 35                            Congestive_heart_failure               1     319
# 6                                 Aspiration_pneumonia               0     313
# 80                                     Hepatic_failure               0     306
# 179                     Sepsis_of_urinary_tract_origin               1     298
# 138                         Other_respiratory_diseases               1     298
# 122                      Other_GI_inflammatory_disease               0     286
# 118                                   Other_GI_disease               0     270
# 87                           Intracerebral_haemorrhage               1     245
# 26                           Cholecystitis_Cholangitis               0     243
# 20                                      Cardiomyopathy               0     240
# 154                     Pulmonary_oedema___non_cardiac               0     239
# 161                                 Respiratory_arrest               1     232
# 143                     Peripheral_artery_bypass_graft               0     215
# 171                                 Rhythm_disturbance               1     203
# 166  Respiratory_neoplasm___mouth__larynx__sinus__t...               0     198
# 4                           Aorto_femoral_bypass_graft               0     194
# 1                          Acute_myocardial_infarction               1     191
# 104    Multi_trauma_with_spinal_injury________________               0     189
# 135                               Other_renal_diseases               0     187
# 2                                      Aortic_aneurysm               0     183
# 18                                   Cardiogenic_shock               0     178
# 79                        Head_trauma_____multi_trauma               1     171
# 186                        Subdural_Epidural_haematoma               0     171
# 125                       Other_cardiovascular_disease               1     167
# 110                               Neurologic_infection               0     159
# 30         Coagulopathy_Neutropaenia_Thrombocytopaenia               0     156
# 158                                     Renal_neoplasm               0     154
# 162                              Respiratory_infection               0     154
# 57                      GI_bleeding___ulcer_laceration               1     152
# 150                         Pregnancy_related_disorder               0     150
# 180                                       Skin_surgery               0     145
# 114                              Neuromuscular_disease               0     145
# 29               Chronic_obstructive_pulmonary_disease               1     143
# 12   Burns_________________________________________...               0     142
# 168      Respiratory_neoplasm_including_larynx_trachea               0     142
# 74                     Genitourinary_surgery_procedure               0     135
# 84                                        Hysterectomy               0     135
# 149                                      Pre_eclampsia               0     131
# 66                                      GI_perforation               0     122
# 157                                    Renal_disorders               1     115
# 42                          Dissecting_aortic_aneurysm               0     103
# 50                             Fistula_Abscess_surgery               0     102
# 65                                      GI_obstruction               1     100
# 101                                  Metabolic_disease               0      99
# 108                       Musculoskeletal_Skin_disease               0      97
# 72             GI_vascular_ischaemia_resection_surgery               0      94
# 90   Isolated_cervical_spine_injury________________...               0      93
# 33                                                Coma               1      91
# 58                               GI_bleeding___varices               0      91
# 52                                         GI_bleeding               0      90
# 192                                    Viral_pneumonia               0      84
# 19                                   Cardiogenic_shock               1      73
# 81                                     Hepatic_failure               1      73
# 69            GI_perforation_rupture__not_peritonitis_               1      71
# 60                                           GI_cancer               0      70
# 107                     Multiple_trauma_excluding_head               1      61
# 153                                 Pulmonary_embolism               1      59
# 49                                  Epidural_haematoma               1      57
# 169      Respiratory_neoplasm_including_larynx_trachea               1      55
# 155                     Pulmonary_oedema___non_cardiac               1      52
# 7                                 Aspiration_pneumonia               1      50
# 55                        GI_bleeding___diverticulosis               1      49
# 132                          Other_metabolic_disorders               1      48
# 70                           GI_vascular_insufficiency               0      48
# 175                                            Seizure               1      47
# 185                           Subarachnoid_haemorrhage               1      45
# 191                             Valvular_heart_surgery               1      44
# 172                           Ruptured_aortic_aneurysm               0      44
# 146                        Peripheral_vascular_disease               1      39
# 37             Coronary_artery_bypass_grafts__________               1      37
# 121                                  Other_GI_diseases               1      36
# 187                        Subdural_Epidural_haematoma               1      35
# 95                                    Liver_transplant               0      34
# 130                       Other_haematologic_disorders               1      34
# 63                                         GI_neoplasm               1      32
# 45                                       Drug_overdose               1      32
# 15                  CABG_with_valve_repair_replacement               1      32
# 134                           Other_neurologic_disease               1      31
# 25                    Cellulitis_Soft_tissue_infection               1      27
# 128                       Other_gynaecological_disease               0      26
# 127                      Other_cardiovascular_diseases               1      26
# 92                                   Kidney_transplant               0      26
# 103        Multi_trauma_with_spinal_injury____________               0      25
# 77              Haemorrhage__post_partum__female_only_               0      25
# 119                                   Other_GI_disease               1      24
# 31         Coagulopathy_Neutropaenia_Thrombocytopaenia               1      24
# 73             GI_vascular_ischaemia_resection_surgery               1      24
# 117                                Orthopaedic_surgery               1      23
# 189                                    Unstable_angina               1      22
# 3                                      Aortic_aneurysm               1      21
# 147                                        Peritonitis               0      21
# 123                      Other_GI_inflammatory_disease               1      20
# 61                                           GI_cancer               1      20
# 100                                     Metabolic_coma               1      19
# 140                                       Pancreatitis               1      18
# 43                          Dissecting_aortic_aneurysm               1      17
# 47                                        Elective_AAA               1      16
# 41                               Diabetic_ketoacidosis               1      16
# 88     Isolated_cervical_spine_injury_________________               0      16
# 83                                        Hypertension               1      15
# 165                        Respiratory_neoplasm___lung               1      14
# 141                                Parasitic_pneumonia               0      13
# 98                       Mechanical_airway_obstruction               1      13
# 113                                Neurologic_neoplasm               1      13
# 39                             Craniotomy_for_neoplasm               1      12
# 173                           Ruptured_aortic_aneurysm               1      11
# 27                           Cholecystitis_Cholangitis               1      10
# 21                                      Cardiomyopathy               1      10
# 23                              Carotid_endarterectomy               1      10
# 105    Multi_trauma_with_spinal_injury________________               1      10
# 53                                         GI_bleeding               1       9
# 76                              Haematological_disease               0       9
# 193                                    Viral_pneumonia               1       9
# 13   Burns_________________________________________...               1       9
# 5                           Aorto_femoral_bypass_graft               1       8
# 71                           GI_vascular_insufficiency               1       8
# 111                               Neurologic_infection               1       8
# 136                               Other_renal_diseases               1       8
# 91   Isolated_cervical_spine_injury________________...               1       7
# 59                               GI_bleeding___varices               1       7
# 67                                      GI_perforation               1       7
# 51                             Fistula_Abscess_surgery               1       7
# 75                     Genitourinary_surgery_procedure               1       6
# 159                                     Renal_neoplasm               1       5
# 9                                               Asthma               1       5
# 115                              Neuromuscular_disease               1       4
# 167  Respiratory_neoplasm___mouth__larynx__sinus__t...               1       4
# 109                       Musculoskeletal_Skin_disease               1       4
# 94                     Laminectomy_Spinal_cord_surgery               1       3
# 144                     Peripheral_artery_bypass_graft               1       3
# 163                              Respiratory_infection               1       2
# 148                                        Peritonitis               1       2
# 142                                Parasitic_pneumonia               1       2
# 181                                       Skin_surgery               1       1
# 85                                        Hysterectomy               1       1
# 89     Isolated_cervical_spine_injury_________________               1       1
# 96                                    Liver_transplant               1       1
# 102                                  Metabolic_disease               1       1
# 151                         Pregnancy_related_disorder               1       1

# %%
cmat = wids[wids['apache_3j_diagnosis_desc'] == 'Sepsis__other_than_urinary'].corr()

# %%
sns.heatmap(cmat,annot=True)

# %% [markdown]
# The most common predictors of Sepsis__other_than_urinary temp_apache, d1_resprate, h1_heartrate

# %%
labeled_df.groupby(['DBSCAN_label','hospital_death']).agg(
    num_patients = ('patient_id','nunique'),
    median_age = ('age','median'),
    median_bmi =('bmi','median'),
    top_elective =('elective_surgery',lambda x: x.value_counts(dropna=False).index[0] ),
    top_gender =('gender',lambda x: x.value_counts(dropna=False).index[0]),
    top_ethnicity =('ethnicity',lambda x: x.value_counts(dropna=False).index[0]),
    top_apache_3j_diagnosis_desc =('apache_3j_diagnosis_desc',lambda x: x.value_counts(dropna=False).index[0]),
    median_temp_apache = ('temp_apache', 'median'),
    median_heartrate_max = ('h1_heartrate_max','median'),
    median_billirubin_apache = ('bilirubin_apache','median')
    
)
# Out:
#                              num_patients  median_age  median_bmi  \
# DBSCAN_label hospital_death
# -1           0                      52701        58.0   29.014391
#              1                       5610        69.0   27.270568
#  0           0                      30921        70.0   26.880273
#              1                       2294        74.0   25.995912
#  1           0                         50        55.0   29.743746
#  2           0                         43        87.0   23.215788
#              1                          7        87.0   22.881253
#  3           0                         37        51.0   25.234375
#              1                          2        50.5   24.854656
#  4           0                         46        74.0   31.712448
#              1                          2        74.0   31.980525
#
#                              top_elective top_gender     top_ethnicity  \
# DBSCAN_label hospital_death
# -1           0                          0          M         Caucasian
#              1                          0          M         Caucasian
#  0           0                          0          M         Caucasian
#              1                          0          M         Caucasian
#  1           0                          0          M         Caucasian
#  2           0                          0          M         Caucasian
#              1                          0          F         Caucasian
#  3           0                          0          M         Caucasian
#              1                          0          F  African_American
#  4           0                          0          M         Caucasian
#              1                          0          M     Other_Unknown
#
#                             top_apache_3j_diagnosis_desc  median_temp_apache  \
# DBSCAN_label hospital_death
# -1           0                Sepsis__other_than_urinary                36.5
#              1                Sepsis__other_than_urinary                36.3
#  0           0                Sepsis__other_than_urinary                36.4
#              1                Sepsis__other_than_urinary                36.3
#  1           0               Acute_myocardial_infarction                36.3
#  2           0                  Congestive_heart_failure                36.5
#              1                Sepsis__other_than_urinary                36.2
#  3           0                  Other_neurologic_disease                36.4
#              1                             Drug_overdose                36.3
#  4           0                        Rhythm_disturbance                36.4
#              1                Sepsis__other_than_urinary                36.4
#
#                              median_heartrate_max  median_billirubin_apache
# DBSCAN_label hospital_death
# -1           0                               93.0                      0.60
#              1                              104.0                      0.90
#  0           0                               84.0                      0.60
#              1                               89.0                      0.80
#  1           0                               73.0                      0.55
#  2           0                               95.0                      1.10
#              1                              102.0                      0.70
#  3           0                               94.5                      0.45
#              1                              106.5                       NaN
#  4           0                               68.0                      0.55
#              1                               57.0                      1.00

# %%
wids['bill']

# %%
# is there a difference in the billrubin 
surv = wids[(wids['apache_3j_diagnosis_desc'] == 'Sepsis__other_than_urinary') & wids['hospital_death'] == 0]['bilirubin_apache'].mean()
died = wids[(wids['apache_3j_diagnosis_desc'] == 'Sepsis__other_than_urinary') & wids['hospital_death'] == 1]['bilirubin_apache'].mean()

# %%
# Survived
wids[(wids['apache_3j_diagnosis_desc'] == 'Sepsis__other_than_urinary') & wids['hospital_death'] == 0] \
['bilirubin_apache'].describe()
# Out:
# count    32678.000000
# mean         1.105789
# std          2.037294
# min          0.100000
# 25%          0.400000
# 50%          0.600000
# 75%          1.000000
# max         51.000000
# Name: bilirubin_apache, dtype: float64

# %%
# Died
wids[(wids['apache_3j_diagnosis_desc'] == 'Sepsis__other_than_urinary') & wids['hospital_death'] == 1] \
['bilirubin_apache'].describe()
# Out:
# count    901.000000
# mean       2.668535
# std        4.678128
# min        0.100000
# 25%        0.600000
# 50%        1.100000
# 75%        2.400000
# max       36.000000
# Name: bilirubin_apache, dtype: float64

# %% [markdown]
# there a few variables where we see a distinct different for the same diagnosis
