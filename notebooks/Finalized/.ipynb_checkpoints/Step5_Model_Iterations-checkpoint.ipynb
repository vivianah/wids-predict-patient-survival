# %% [markdown]
# # Model Iterations:
#
# Trying different models:
# - Random Forest
# - XG Boost
# - LightGBM
#
# With different sampling methods in term of imbalanced classes:
# - undersampling m

# %%
# importing standard packages
import pandas as pd
import numpy as np 
from scipy import stats 

# importing the plot funnctions
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 

# preprocessing/ model selection 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# importing the classifiers 
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

# importing the metrics 
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, classification_report,f1_score
from sklearn.metrics import roc_curve

# oversampling techniques 
from imblearn.over_sampling import SMOTE

# importing model saving package 
from joblib import dump, load

# %% [markdown]
# ## Functions for Notebooks

# %%
def draw_conf_mat(mat):
    
    """
    Draw confusion matrix
    
    Parameters:
    ------------------
    mat:                ndarray of shape (n_classes, n_classes) 
                        confusion matrix

    """
    
    import matplotlib.pyplot as plt 
    import seaborn as sns
    
    fig, ax = plt.subplots(figsize=(8, 8))
    sns.heatmap(mat, annot=True, fmt="d",
            xticklabels=['0', '1'],
            yticklabels=['0', '1'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    ax.set_ylim([0,2])
    ax.invert_yaxis()
    plt.show()
    
    return ax

# %%
def draw_roc_curve(y_true, y_proba):
    
    """
    Draw baseline and model roc curve
    
    Parameters:
    ------------------
    y_true:             array-like of shape (n_samples,) 
                        True label of target (y)
                        
    y_proba             array-like of shape (n_samples,)
                        The predicted probability of target (y)
    """
    
    
    base_fpr, base_tpr, _ = roc_curve(y_true, [1 for _ in range(len(y_true))])
    model_fpr, model_tpr, _ = roc_curve(y_true, y_proba)
    
    fig, ax = plt.subplots(figsize=(10, 6))
    plt.plot(base_fpr, base_tpr, 'b', label = 'baseline')
    plt.plot(model_fpr, model_tpr, 'r', label = 'model')
    plt.legend();
    plt.xlabel('False Positive Rate'); plt.ylabel('True Positive Rate'); plt.title('ROC Curves');
    
    return ax

# %%
def metrics_imbalanced(your_confusion_matrix, y_true, y_proba):
    
    """
    Print precision, recall, fallout and auroc score based on the confusion matrix. 
    
    Parameters:
    ------------------
    your_confusion_matrix:                ndarray of shape (n_classes, n_classes) 
                                          confusion matrix
                                          
    y_true:                               array-like of shape (n_samples,) 
                                          True label of target (y)
                                          
    y_proba:                              y_proba             array-like of shape (n_samples,)
                                          The predicted probability of target (y)
    """
    
    # Model evaluation metrics. 
    tp = your_confusion_matrix[1,1]
    fn = your_confusion_matrix[1,0]
    fp = your_confusion_matrix[0,1]
    tn = your_confusion_matrix[0,0]
    auroc = roc_auc_score(y_true, y_proba)
    
    print('Precision = %0.3f'%(tp/(tp+fp)))
    print('Recall (TPR) = %0.3f'%(tp/(tp+fn)))
    print('Fallout (FPR) = %0.3f'%(fp/(fp+tn)))
    print('Roc_auc_score = %0.3f'%auroc)

# %%
def resampling_unbalanced(train_x, train_y, sample_method):
    """ 

    Parameters
    ----------
    train_x : test_x 
            pd.DataFrame
    train_y : train_y 
            pd.DataFrame
    sample_method: 'over' or 'under'
            string

    Returns
    -------
    train_x : resampled train_x
                pd.DataFrame
    train_y : resampled train_y
                pd.DataFrame
        

    """
    
    
    if sample_method == "over":
        oversample = SMOTE()
        train_x_ros, train_y_ros = oversample.fit_resample(X_train, y_train)
        
        return train_x_ros, train_y_ros
        
    if sample_method == "under":
        # Concate X and Y train
        trainData = pd.concat([train_x, train_y],axis=1)
        # Class count
        count_class_0, count_class_1 = trainData["hospital_death"].value_counts()

        # Divide by class
        df_class_0 = trainData[trainData['hospital_death'] == 0]
        df_class_1 = trainData[trainData['hospital_death'] == 1]
        
        # Sample the majority class
        df_class_0_under = df_class_0.sample(count_class_1)
        
        # Put the train dataset together
        train_rus = pd.concat([df_class_0_under, df_class_1], axis=0)
        train_x_rus = train_rus.drop("hospital_death", axis = 1)
        train_y_rus = pd.DataFrame(train_rus['hospital_death'])
        
        return train_x_rus, train_y_rus

# %% [markdown]
# ## Bring in the X_wids and y_wids from the WIDS_Feature_Engineer.ipynb
# Run the WIDS Feature Engineer Notebook first in order to grab the dataframes

# %%
# grab the stored data frames
# %store -r X_wids
# %store -r y_wids

# %%
X_wids.shape, y_wids.shape
# Out:
# ((91713, 598), (91713, 1))

# %% [markdown]
# ## Train Test Split without Correction of Imbalanced Data

# %%
# Split train-test dataset 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_wids, y_wids, test_size = 0.2, random_state = 31, stratify = y_wids)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (73370, 598) (18343, 598) (73370, 1) (18343, 1)

# %% [markdown]
# ## Models with No Correction Of Imbalanced Data

# %%
# create a dictionary of classifers with the hyperparameters you would like to try 
classifiers = {'XG': XGBClassifier(n_jobs = 1, learning_rate = .1, n_estimators = 100, objective = 'binary:hinge', booster='gbtree', max_depth = 7 ),
              'RF': RandomForestClassifier(n_estimators= 100, max_depth = 7),
              'LGB': LGBMClassifier(booster ='gbtree', n_estimators = 100, learning_rate = .1, max_depth = 7, objective ='binary')}

# %%
# keys of the classifiers 
selected_clfs = ['XG','RF','LGB']

# %%
# create the clf_matrix 
clf_matrix = pd.DataFrame(columns = ['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV'])

# for every classifer in the selected classifers list
for idx, classifier in enumerate(selected_clfs):

    # get the classifer and hyperparameters from the model
    clf = classifiers[classifier]

    # fit the model 
    clf.fit(X_train,y_train.values.ravel())
    print(f"-------- classifier being run is {classifier} ---------")

    print(f"-------- saving the the model ---------")
    # Write the model to file
    dump(clf, '{}.joblib'.format(classifier)) 

    print(f"-------- computing y_predict, y_prob, y_train_predict ---------")
    # prediction of y based on X_test
    y_predict = clf.predict(X_test)
    # prediction of y probability based on X_test
    y_proba = clf.predict_proba(X_test)[:,1]
    # prediction of y based on X_train
    y_train_predict = clf.predict(X_train)

    print(f"-------- creating the confusion matrix ---------") 
    # confusion matrix 
    cmat = confusion_matrix(y_test.values.ravel(), y_predict)
    # tp, fn, fp, tn
    tp = cmat[1,1]
    fn = cmat[1,0]
    fp = cmat[0,1]
    tn = cmat[0,0]

    print(f"-------- calculating the metrics ---------") 
    #precision score on test
    p_score_test = precision_score(y_test.values.ravel(), y_predict)

    #recall score on test
    r_score_test = tp/(tp+fn) 

    #FPR score on test
    fpr_test = fp/(fp+tn)

    #AUROC score on test
    auroc_test = roc_auc_score(y_test.values.ravel(), y_proba)

    #f1 score on test
    f1_test = f1_score(y_test.values.ravel(), y_predict)

    #f1 score on train
    f1_train = f1_score(y_train.values.ravel(), y_train_predict)

    #f1 score on cross validation 
    k_fold = 4
    f1_cv = cross_val_score(clf, X_train, y_train.values.ravel(), cv=k_fold, scoring = 'f1')
    print(f"Cross Validation is on {k_fold} folds.")

    print(f"-------- append values to the model matrix  ---------") 

    # append to matrix
    df2 = pd.DataFrame([[classifier,p_score_test,r_score_test, fpr_test, auroc_test, f1_test, f1_train, f1_cv]], 
                       columns=['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV'])
    
    clf_matrix = pd.concat([df2, clf_matrix])
# Out:
# -------- classifier being run is XG ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------
# -------- classifier being run is RF ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------
# -------- classifier being run is LGB ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------

# %%
# Draw confusion matrix for each model 
for classifier in selected_clfs:

  # Load model saved
  clf = load('{}.joblib'.format(classifier)) 

  # Predict y based on X_test
  y_predict = clf.predict(X_test)

  # confusion matrix
  cm = confusion_matrix(y_test, y_predict)

  # Draw
  print(classifier)
  draw_conf_mat(cm)
# Out:
# XG
# RF
# LGB

# %% [markdown]
# ## Models with Correction Of Imbalanced Data Using Undersampling
# Note: Undersampling should not be performed on the validation set. Therefore we will build a pipeline of undersampling and modeling.

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline, make_pipeline

# %%
# create a dictionary of classifers with the hyperparameters you would like to try 
classifiers = {'XG_U': XGBClassifier(n_jobs = 1, learning_rate = .1, n_estimators = 100, objective = 'binary:hinge', booster='gbtree', max_depth = 7 ),
              'RF_U': RandomForestClassifier(n_estimators= 100, max_depth = 7),
              'LGB_U': LGBMClassifier(booster ='gbtree', n_estimators = 100, learning_rate = .1, max_depth = 7, objective ='binary')}

# %%
# keys for the classifiers 
selected_clfs = ['XG_U', 'RF_U', 'LGB_U']

# %% [markdown]
# Undersampling data using 0.8 ratio (minority:majority)

# %%
clf_under_matrix = pd.DataFrame(columns = ['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV', 'recall_CV'])

# for every classifer in the selected classifers list
for idx, classifier in enumerate(selected_clfs):

    # get the classifer and hyperparameters from the model
    clf = classifiers[classifier]
    
    # Make pipeline
    rus = RandomUnderSampler(sampling_strategy = 1, random_state=42)
    clf_rus_pipeline = make_pipeline(rus,clf)
    
    # fit the model 
    clf_rus_pipeline.fit(X_train.values, y_train.values.ravel())
    print(f"-------- classifier being run is {classifier} ---------")

    print(f"-------- saving the the model ---------")
    # Write the model/pipeline to file
    dump(clf_rus_pipeline, '{}.joblib'.format(classifier)) 

    print(f"-------- computing y_predict, y_prob, y_train_predict ---------")
    # prediction of y based on X_test. RUS does not do anything to X_test. 
    y_predict = clf_rus_pipeline.predict(X_test.values)
    # prediction of y probability based on X_test
    y_proba = clf_rus_pipeline.predict_proba(X_test.values)[:,1]
    # prediction of y based on X_train
    y_train_predict = clf_rus_pipeline.predict(X_train.values)

    print(f"-------- creating the confusion matrix ---------") 
    # confusion matrix 
    cmat = confusion_matrix(y_test.values.ravel(), y_predict)
    # tp, fn, fp, tn
    tp = cmat[1,1]
    fn = cmat[1,0]
    fp = cmat[0,1]
    tn = cmat[0,0]

    print(f"-------- calculating the metrics ---------") 
    #precision score on test
    p_score_test = precision_score(y_test.values.ravel(), y_predict)

    #recall score on test
    r_score_test = tp/(tp+fn) 

    #FPR score on test
    fpr_test = fp/(fp+tn)

    #AUROC score on test
    auroc_test = roc_auc_score(y_test.values.ravel(), y_proba)

    #f1 score on test
    f1_test = f1_score(y_test.values.ravel(), y_predict)

    #f1 score on train
    f1_train = f1_score(y_train.values.ravel(), y_train_predict)

    #f1 score on cross validation 
    k_fold = 4
    f1_cv = cross_val_score(clf_rus_pipeline, X_train.values, y_train.values.ravel(), 
                            cv=k_fold, scoring = 'f1')
    recall_cv = cross_val_score(clf_rus_pipeline, X_train.values, y_train.values.ravel(), 
                            cv=k_fold, scoring = 'recall')
    print(f"Cross Validation is on {k_fold} folds.")

    print(f"-------- append values to the model matrix  ---------") 

    # append to matrix
    df2 = pd.DataFrame([[classifier,p_score_test,r_score_test, fpr_test, auroc_test, f1_test, f1_train, f1_cv, recall_cv]], 
                       columns=['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV', 'recall_CV'])
    
    clf_under_matrix = pd.concat([df2, clf_under_matrix])
# Out:
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# -------- classifier being run is XG_U ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# -------- classifier being run is RF_U ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# -------- classifier being run is LGB_U ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------

# %%
# Draw confusion matrix for each model 
for classifier in selected_clfs:

  # Load model saved
  clf = load('{}.joblib'.format(classifier)) 

  # Predict y based on X_test
  y_predict = clf.predict(X_test.values)

  # confusion matrix
  cm = confusion_matrix(y_test, y_predict)

  # Draw
  print(classifier)
  draw_conf_mat(cm)
# Out:
# XG_U
# RF_U
# LGB_U

# %% [markdown]
# ## Models with Correction Of Imbalanced Data Using Oversampling SMOTE
# Again, smote needs to be performed outside of validation set. Make pipeline first.

# %%
# create a dictionary of classifers with the hyperparameters you would like to try 
classifiers = {'XG_O': XGBClassifier(n_jobs = 1, learning_rate = .1, n_estimators = 100, objective = 'binary:hinge', booster='gbtree', max_depth = 7 ),
              'RF_O': RandomForestClassifier(n_estimators= 100, max_depth = 7),
              'LGB_O': LGBMClassifier(booster ='gbtree', n_estimators = 100, learning_rate = .1, max_depth = 7, objective ='binary')}

# %%
selected_clfs = ['XG_O', 'RF_O', 'LGB_O' ]

# %% [markdown]
# Oversampling using 0.8 ratio as well

# %%
clf_over_matrix = pd.DataFrame(columns = ['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV', 'recall_cv'])

# for every classifer in the selected classifers list
for idx, classifier in enumerate(selected_clfs):
    
    # get the classifer and hyperparameters from the model
    clf = classifiers[classifier]
    
    # Make pipeline
    ros = SMOTE(sampling_strategy = 1, random_state=42)
    clf_ros_pipeline = make_pipeline(ros,clf)

    # fit the model 
    clf_ros_pipeline.fit(X_train.values,y_train.values.ravel())
    print(f"-------- classifier being run is {classifier} ---------")

    print(f"-------- saving the the model ---------")
    # Write the model to file
    dump(clf_ros_pipeline, '{}.joblib'.format(classifier)) 

    print(f"-------- computing y_predict, y_prob, y_train_predict ---------")
    # prediction of y based on X_test
    y_predict = clf_ros_pipeline.predict(X_test.values)
    # prediction of y probability based on X_test
    y_proba = clf_ros_pipeline.predict_proba(X_test.values)[:,1]
    # prediction of y based on X_train
    y_train_predict = clf_ros_pipeline.predict(X_train.values)

    print(f"-------- creating the confusion matrix ---------") 
    # confusion matrix 
    cmat = confusion_matrix(y_test.values.ravel(), y_predict)
    # tp, fn, fp, tn
    tp = cmat[1,1]
    fn = cmat[1,0]
    fp = cmat[0,1]
    tn = cmat[0,0]

    print(f"-------- calculating the metrics ---------") 
    #precision score on test
    p_score_test = precision_score(y_test.values.ravel(), y_predict)

    #recall score on test
    r_score_test = tp/(tp+fn) 

    #FPR score on test
    fpr_test = fp/(fp+tn)

    #AUROC score on test
    auroc_test = roc_auc_score(y_test.values.ravel(), y_proba)

    #f1 score on test
    f1_test = f1_score(y_test.values.ravel(), y_predict)

    #f1 score on train
    f1_train = f1_score(y_train.values.ravel(), y_train_predict)

    #f1 score on cross validation 
    k_fold = 4
    f1_cv = cross_val_score(clf_ros_pipeline, X_train.values, y_train.values.ravel(), 
                            cv=k_fold, scoring = 'f1')
    recall_cv = cross_val_score(clf_ros_pipeline, X_train.values, y_train.values.ravel(), 
                            cv=k_fold, scoring = 'recall')
    print(f"Cross Validation is on {k_fold} folds.")

    print(f"-------- append values to the model matrix  ---------") 

    # append to matrix
    df2 = pd.DataFrame([[classifier,p_score_test,r_score_test, fpr_test, auroc_test, f1_test, f1_train, f1_cv, recall_cv]], 
                       columns=['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV', 'recall_cv'])
    
    clf_over_matrix = pd.concat([df2, clf_over_matrix])
# Out:
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# -------- classifier being run is XG_O ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# -------- classifier being run is RF_O ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# -------- classifier being run is LGB_O ---------
# -------- saving the the model ---------
# -------- computing y_predict, y_prob, y_train_predict ---------
# -------- creating the confusion matrix ---------
# -------- calculating the metrics ---------
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.
# -------- append values to the model matrix  ---------

# %%
# Draw confusion matrix for each model 
for classifier in selected_clfs:

  # Load model saved
  clf = load('{}.joblib'.format(classifier)) 

  # Predict y based on X_test
  y_predict = clf.predict(X_test.values)

  # confusion matrix
  cm = confusion_matrix(y_test, y_predict)

  # Draw
  print(classifier)
  draw_conf_mat(cm)
# Out:
# XG_O
# RF_O
# LGB_O

# %%
clf_over_matrix.explode('recall_cv')
# Out:
#    model  precision_test  recall_test  FPR_test  AUROC_test   f1_test  \
# 0  LGB_O        0.677223     0.351232  0.015811    0.895908  0.462562
# 0  LGB_O        0.677223     0.351232  0.015811    0.895908  0.462562
# 0  LGB_O        0.677223     0.351232  0.015811    0.895908  0.462562
# 0  LGB_O        0.677223     0.351232  0.015811    0.895908  0.462562
# 0   RF_O        0.339616     0.614656  0.112888    0.858008  0.437500
# 0   RF_O        0.339616     0.614656  0.112888    0.858008  0.437500
# 0   RF_O        0.339616     0.614656  0.112888    0.858008  0.437500
# 0   RF_O        0.339616     0.614656  0.112888    0.858008  0.437500
# 0   XG_O        0.732824     0.303222  0.010442    0.646390  0.428954
# Out:
#   model  precision_test  recall_test  FPR_test  AUROC_test   f1_test  \
# 0   LGB        0.703896     0.342388  0.013604    0.901638  0.460688
# 0   LGB        0.703896     0.342388  0.013604    0.901638  0.460688
# 0   LGB        0.703896     0.342388  0.013604    0.901638  0.460688
# 0   LGB        0.703896     0.342388  0.013604    0.901638  0.460688
# 0    RF        0.757143     0.167404  0.005072    0.865350  0.274185
# 0    RF        0.757143     0.167404  0.005072    0.865350  0.274185
# 0    RF        0.757143     0.167404  0.005072    0.865350  0.274185
# 0    RF        0.757143     0.167404  0.005072    0.865350  0.274185
# 0    XG        0.714719     0.297536  0.011217    0.643160  0.420161
# 0    XG        0.714719     0.297536  0.011217    0.643160  0.420161
# 0    XG        0.714719     0.297536  0.011217    0.643160  0.420161
# 0    XG        0.714719     0.297536  0.011217    0.643160  0.420161
#
#    f1_train     f1_CV
# 0  0.594870  0.440461
# 0  0.594870  0.462649
# 0  0.594870  0.451915
# 0  0.594870  0.464225
# 0  0.327635  0.281137
# 0  0.327635  0.273859
# 0  0.327635  0.261506
# 0  0.327635  0.294661
# 0  0.646855  0.402294
# 0  0.646855  0.418522
# 0  0.646855  0.398927
# 0  0.646855   0.40949

# %%
## Warnings seen on terminal

### [LightGBM] [Warning] Unknown parameter: booster
### [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves

# %% [markdown]
# ### Feature Importance

# %%
lgb = load("LGB.joblib")
baseline_importances = pd.DataFrame({'feature':X_wids.columns,'importance':np.round(lgb.feature_importances_,3)})
baseline_importances = baseline_importances.sort_values('importance',ascending=False).set_index('feature')
baseline_importances.head(600)
# Out:
#                                                     importance
# feature
# age                                                         82
# d1_heartrate_min                                            71
# pre_icu_los_days                                            57
# d1_resprate_min                                             51
# bmi                                                         49
# d1_temp_max                                                 47
# d1_glucose_min                                              42
# d1_platelets_min                                            39
# d1_sodium_max                                               38
# d1_test_total                                               38
# d1_spo2_min                                                 38
# d1_hco3_max                                                 34
# d1_arterial_ph_min                                          32
# urineoutput_apache                                          31
# d1_arterial_ph_max                                          31
# d1_temp_min                                                 30
# d1_heartrate_max                                            30
# d1_arterial_po2_min                                         30
# weight                                                      29
# d1_bun_max                                                  28
# d1_resprate_max                                             27
# ventilated_apache                                           27
# d1_bun_min                                                  26
# eartrate_min_change                                         26
# d1_wbc_min                                                  25
# glucose_apache                                              25
# missing_test_total                                          23
# heart_rate_apache                                           23
# d1_sysbp_max                                                23
# h1_lactate_avg                                              23
# eartrate_max_change                                         22
# d1_heartrate_diff                                           21
# d1_mbp_min                                                  21
# d1_calcium_min                                              21
# height                                                      21
# d1_spo2_max                                                 21
# d1_temp_diff                                                21
# d1_potassium_min                                            20
# d1_sysbp_min                                                20
# apache_3j_diagnosis_desc_Cardiac_arrest                     20
# d1_hemaglobin_max                                           20
# d1_creatinine_min                                           20
# d1_bilirubin_max                                            18
# d1_hco3_min                                                 18
# d1_ppv                                                      18
# creatinine_apache                                           18
# gcs_score                                                   18
# gcs_motor_apache                                            18
# solid_tumor_with_metastasis                                 17
# d1_creatinine_max                                           17
# d1_glucose_max                                              17
# d1_hemaglobin_min                                           16
# d1_wbc_max                                                  16
# d1_hematocrit_min                                           16
# apache_3j_bodysystem_Neurological                           16
# gcs_eyes_apache                                             15
# d1_sysbp_noninvasive_max                                    15
# wbc_apache                                                  15
# d1_bilirubin_min                                            15
# d1_arterial_pco2_min                                        15
# d1_arterial_pco2_max                                        15
# d1_sysbp_diff                                               15
# elective_surgery                                            15
# map_apache                                                  14
# temp_apache                                                 14
# d1_sodium_min                                               14
# d1_glucose_diff                                             14
# diasbp_med_diff                                             14
# h1_resprate_min                                             14
# bun_apache                                                  14
# icu_admit_source_Operating_Room___Recovery                  14
# d1_arterial_po2_max                                         13
# d1_sysbp_noninvasive_min                                    13
# apache_3j_diagnosis_desc_Stroke                             13
# d1_platelets_max                                            13
# d1_inr_min                                                  13
# apache_3j_bodysystem_Metabolic                              13
# h1_mbp_avg                                                  12
# h1_ppv                                                      12
# resprate_apache                                             12
# d1_diasbp_max                                               12
# h1_resprate_avg                                             12
# mbp_med_diff                                                12
# h1_inr_avg                                                  12
# d1_diasbp_diff                                              12
# gcs_unable_apache                                           12
# diasbp_max_change                                           11
# mbp_max_change                                              11
# apache_3j_diagnosis_desc_Bacterial_pneumonia                11
# d1_sodium_diff                                              11
# heartrate_med_diff                                          11
# spo2_min_change                                             11
# d1_calcium_max                                              11
# d1_albumin_max                                              10
# h1_mbp_min                                                  10
# d1_hematocrit_diff                                          10
# hematocrit_apache                                           10
# lactate_med_diff                                            10
# resprate_med_diff                                           10
# d1_inr_max                                                  10
# d1_albumin_min                                              10
# h1_albumin_avg                                              10
# d1_diasbp_min                                               10
# h1_diasbp_avg                                               10
# d1_arterial_pco2_diff                                        9
# bilirubin_apache                                             9
# hospital_id_70                                               9
# sysbp_med_diff                                               9
# hospital_id_21                                               9
# h1_heartrate_min                                             9
# hospital_id_76                                               9
# d1_potassium_max                                             9
# h1_temp_max                                                  9
# d1_mbp_noninvasive_min                                       9
# d1_mbp_max                                                   9
# h1_resprate_max                                              9
# resprate_min_change                                          9
# temp_max_change                                              9
# albumin_apache                                               8
# h1_sysbp_avg                                                 8
# creatinine_med_diff                                          8
# spo2_med_diff                                                8
# icu_admit_source_Other_Hospital                              8
# apache_3j_bodysystem_Sepsis                                  8
# h1_temp_min                                                  8
# h1_temp_avg                                                  8
# d1_potassium_diff                                            8
# creatine_risk                                                8
# h1_sysbp_min                                                 8
# d1_spo2_diff                                                 8
# diasbp_min_change                                            8
# d1_resprate_diff                                             8
# temp_med_diff                                                8
# arterial_ph_min_change                                       7
# d1_lactate_diff                                              7
# h1_sysbp_noninvasive_min                                     7
# h1_spo2_max                                                  7
# arterial_ph_med_diff                                         7
# hematocrit_med_diff                                          7
# h1_bun_avg                                                   7
# d1_hematocrit_max                                            7
# h1_inr_diff                                                  7
# icu_type_Neuro_ICU                                           7
# glucose_min_change                                           6
# d1_creatinine_diff                                           6
# h1_heartrate_diff                                            6
# hospital_id_176                                              6
# h1_heartrate_max                                             6
# d1_mbp_diff                                                  6
# lactate_level                                                6
# lactate_min_change                                           6
# spo2_max_change                                              6
# h1_wbc_avg                                                   6
# urine_flag                                                   6
# gcs_verbal_apache                                            6
# h1_glucose_max                                               6
# h1_arterial_pco2_avg                                         6
# apache_3j_diagnosis_desc_Other_respiratory_dise...           5
# creatinine_max_change                                        5
# temp_min_change                                              5
# hospital_id_2                                                5
# sysbp_min_change                                             5
# d1_arterial_po2_diff                                         5
# apache_3j_diagnosis_desc_Head_trauma_____multi_...           5
# hco3_med_diff                                                5
# d1_hemaglobin_diff                                           5
# mbp_min_change                                               5
# hospital_id_145                                              5
# glucose_max_change                                           5
# ematocrit_min_change                                         5
# hospital_id_26                                               5
# apache_3j_diagnosis_desc_Intracerebral_haemorrhage           5
# h1_sysbp_max                                                 5
# h1_diasbp_max                                                5
# h1_arterial_po2_avg                                          5
# cc_total                                                     5
# h1_test_total                                                5
# h1_glucose_min                                               5
# h1_platelets_avg                                             5
# hospital_admit_source_Direct_Admit                           5
# h1_mbp_noninvasive_min                                       5
# h1_hco3_avg                                                  5
# sodium_apache                                                5
# h1_diasbp_min                                                4
# hospital_admit_source_unknown                                4
# glucose_med_diff                                             4
# h1_creatinine_avg                                            4
# h1_heartrate_avg                                             4
# wbc_min_change                                               4
# sysbp_max_change                                             4
# glucose_risk                                                 4
# platelets_level                                              4
# diabetes_mellitus                                            4
# h1_diasbp_noninvasive_max                                    4
# hospital_admit_source_Emergency_Department                   4
# creatinine_min_change                                        4
# d1_mbp_noninvasive_max                                       4
# h1_sysbp_noninvasive_max                                     4
# resprate_max_change                                          4
# potassium_max_change                                         4
# pao2fio2ratio_min_change                                     4
# h1_mbp_noninvasive_max                                       4
# h1_arterial_ph_diff                                          4
# h1_diasbp_diff                                               4
# h1_mbp_diff                                                  4
# apache_3j_bodysystem_Cardiovascular                          4
# h1_arterial_ph_avg                                           4
# h1_temp_diff                                                 4
# d1_albumin_diff                                              4
# d1_calcium_diff                                              4
# h1_spo2_diff                                                 4
# d1_arterial_ph_diff                                          4
# d1_hco3_diff                                                 3
# emaglobin_min_change                                         3
# arterial_pco2_min_change                                     3
# arterial_ph_max_change                                       3
# apache_3j_diagnosis_desc_Acute_myocardial_infar...           3
# h1_sysbp_diff                                                3
# bun_min_change                                               3
# h1_hemaglobin_avg                                            3
# apache_3j_diagnosis_desc_Coronary_artery_bypass...           3
# ethnicity_African_American                                   3
# apache_3j_diagnosis_desc_Congestive_heart_failure            3
# d1_bun_diff                                                  3
# pao2fio2ratio_max_change                                     3
# potassium_min_change                                         3
# d1_diasbp_noninvasive_min                                    3
# d1_diasbp_noninvasive_max                                    3
# hospital_id_47                                               3
# hospital_id_155                                              3
# hospital_id_100                                              3
# apache_3j_diagnosis_desc_GI_bleeding___ulcer_la...           3
# hospital_id_43                                               3
# hospital_id_196                                              3
# h1_bilirubin_avg                                             3
# h1_sodium_avg                                                3
# h1_glucose_avg                                               3
# potassium_med_diff                                           3
# hospital_id_30                                               3
# h1_pao2fio2ratio_avg                                         3
# d1_wbc_diff                                                  3
# bilirubin_risk                                               3
# h1_potassium_avg                                             3
# h1_calcium_avg                                               3
# immunosuppression                                            3
# wbc_level                                                    3
# arterial_po2_med_diff                                        3
# apache_3j_diagnosis_desc_Respiratory_neoplasm_i...           2
# apache_3j_bodysystem_Respiratory                             2
# h1_spo2_avg                                                  2
# sodium_min_change                                            2
# bun_med_diff                                                 2
# calcium_med_diff                                             2
# apache_3j_diagnosis_desc_GI_bleeding___divertic...           2
# hospital_id_101                                              2
# apache_3j_diagnosis_desc_GI_cancer                           2
# apache_post_operative                                        2
# gender_F                                                     2
# hospital_id_112                                              2
# d1_pao2fio2ratio_diff                                        2
# apache_2_bodysystem_Undefined_diagnoses                      2
# hospital_id_204                                              2
# co3_min_change                                               2
# d1_platelets_diff                                            2
# apache_3j_diagnosis_desc_Sepsis_of_urinary_trac...           2
# hospital_admit_source_Floor                                  2
# hospital_id_92                                               2
# pao2fio2ratio_med_diff                                       2
# h1_glucose_diff                                              2
# apache_3j_diagnosis_desc_Sepsis__other_than_uri...           2
# h1_hematocrit_avg                                            2
# hospital_id_98                                               2
# hospital_id_179                                              1
# apache_3j_diagnosis_desc_Chronic_obstructive_pu...           1
# apache_2_bodysystem_Renal_Genitourinary                      1
# hospital_id_133                                              1
# hospital_id_14                                               1
# apache_3j_diagnosis_desc_GI_neoplasm                         1
# hospital_id_19                                               1
# hospital_id_174                                              1
# apache_3j_diagnosis_desc_CABG_with_valve_repair...           1
# hospital_id_18                                               1
# apache_3j_bodysystem_Trauma                                  1
# hospital_id_54                                               1
# hospital_id_29                                               1
# ethnicity_Hispanic                                           1
# ethnicity_Caucasian                                          1
# hospital_id_55                                               1
# apache_3j_diagnosis_desc_Craniotomy_for_neoplasm             1
# hospital_id_64                                               1
# icu_type_Cardiac_ICU                                         1
# apache_3j_diagnosis_desc_Dissecting_aortic_aneu...           1
# hospital_id_157                                              1
# hospital_id_51                                               1
# apache_3j_diagnosis_desc_Epidural_haematoma                  1
# apache_3j_bodysystem_Gastrointestinal                        1
# ethnicity_Other_Unknown                                      1
# hemaglobin_med_diff                                          1
# arterial_po2_max_change                                      1
# h1_creatinine_diff                                           1
# h1_hco3_diff                                                 1
# h1_hemaglobin_diff                                           1
# apache_3j_diagnosis_desc_Other_GI_disease                    1
# apache_3j_diagnosis_desc_Respiratory_neoplasm__...           1
# h1_resprate_diff                                             1
# lymphoma                                                     1
# platelets_min_change                                         1
# sodium_max_change                                            1
# wbc_max_change                                               1
# apache_3j_diagnosis_desc_Other_neurologic_disease            1
# hepatic_failure                                              1
# arterial_po2_min_change                                      1
# h1_sodium_diff                                               1
# co3_max_change                                               1
# apache_3j_diagnosis_desc_Valvular_heart_surgery              1
# wbc_med_diff                                                 1
# h1_spo2_min                                                  1
# d1_bilirubin_diff                                            1
# h1_diasbp_noninvasive_min                                    1
# h1_mbp_max                                                   1
# apache_3j_bodysystem_Gynecological                           0
# apache_3j_diagnosis_desc_Pregnancy_related_diso...           0
# icu_type_CTICU                                               0
# apache_3j_diagnosis_desc_Pre_eclampsia                       0
# apache_2_bodysystem_Cardiovascular                           0
# icu_type_MICU                                                0
# apache_3j_bodysystem_unknown                                 0
# apache_3j_diagnosis_desc_Respiratory_neoplasm__...           0
# icu_type_Med_Surg_ICU                                        0
# apache_3j_diagnosis_desc_Pulmonary_embolism                  0
# apache_3j_bodysystem_Genitourinary                           0
# icu_type_SICU                                                0
# apache_3j_diagnosis_desc_Pulmonary_oedema___non...           0
# apache_3j_diagnosis_desc_Respiratory_infection               0
# apache_3j_bodysystem_Musculoskeletal_Skin                    0
# apache_3j_diagnosis_desc_Renal_disorders                     0
# icu_type_CSICU                                               0
# apache_3j_bodysystem_Hematological                           0
# apache_3j_diagnosis_desc_Renal_neoplasm                      0
# apache_3j_diagnosis_desc_Respiratory_arrest                  0
# apache_3j_diagnosis_desc_Laminectomy_Spinal_cor...           0
# icu_type_CCU_CTICU                                           0
# hospital_admit_source_Other                                  0
# apache_3j_diagnosis_desc_Viral_pneumonia                     0
# apache_3j_diagnosis_desc_Unstable_angina                     0
# gender_M                                                     0
# gender_unknown                                               0
# hospital_admit_source_Acute_Care_Floor                       0
# hospital_admit_source_Chest_Pain_Center                      0
# apache_3j_diagnosis_desc_Subdural_Epidural_haem...           0
# apache_3j_diagnosis_desc_Subarachnoid_haemorrhage            0
# apache_3j_diagnosis_desc_Skin_surgery                        0
# hospital_admit_source_ICU                                    0
# hospital_admit_source_ICU_to_SDU                             0
# hospital_admit_source_Observation                            0
# hospital_admit_source_Operating_Room                         0
# hospital_admit_source_Other_Hospital                         0
# icu_stay_type_transfer                                       0
# hospital_admit_source_Other_ICU                              0
# hospital_admit_source_PACU                                   0
# hospital_admit_source_Recovery_Room                          0
# hospital_admit_source_Step_Down_Unit__SDU_                   0
# icu_admit_source_Accident___Emergency                        0
# icu_admit_source_Floor                                       0
# apache_3j_diagnosis_desc_Seizure                             0
# icu_admit_source_Other_ICU                                   0
# apache_3j_diagnosis_desc_Ruptured_aortic_aneurysm            0
# apache_2_bodysystem_Gastrointestinal                         0
# icu_stay_type_admit                                          0
# icu_stay_type_readmit                                        0
# apache_3j_diagnosis_desc_Rhythm_disturbance                  0
# icu_admit_source_unknown                                     0
# apache_2_bodysystem_Neurologic                               0
# apache_2_bodysystem_Haematologic                             0
# apache_3j_diagnosis_desc_Peritonitis                         0
# apache_3j_diagnosis_desc_Neuromuscular_disease               0
# apache_3j_diagnosis_desc_Drug_overdose                       0
# apache_3j_diagnosis_desc_Elective_AAA                        0
# apache_3j_diagnosis_desc_Fistula_Abscess_surgery             0
# apache_3j_diagnosis_desc_GI_bleeding                         0
# apache_3j_diagnosis_desc_Neurologic_neoplasm                 0
# apache_3j_diagnosis_desc_Neurologic_infection                0
# apache_3j_diagnosis_desc_GI_bleeding___varices               0
# apache_3j_diagnosis_desc_Musculoskeletal_Skin_d...           0
# apache_3j_diagnosis_desc_Multiple_trauma_exclud...           0
# apache_3j_diagnosis_desc_Multi_trauma_with_spin...           0
# apache_3j_diagnosis_desc_GI_obstruction                      0
# apache_3j_diagnosis_desc_Multi_trauma_with_spin...           0
# apache_3j_diagnosis_desc_GI_perforation                      0
# apache_3j_diagnosis_desc_GI_perforation_rupture...           0
# apache_3j_diagnosis_desc_GI_vascular_insufficiency           0
# apache_3j_diagnosis_desc_GI_vascular_ischaemia_...           0
# hospital_id_168                                              0
# hospital_id_167                                              0
# hospital_id_192                                              0
# hospital_id_195                                              0
# hospital_id_38                                               0
# hospital_id_3                                                0
# hospital_id_37                                               0
# hospital_id_36                                               0
# hospital_id_35                                               0
# hospital_id_34                                               0
# hospital_id_33                                               0
# hospital_id_32                                               0
# hospital_id_31                                               0
# hospital_id_27                                               0
# hospital_id_197                                              0
# hospital_id_24                                               0
# hospital_id_23                                               0
# hospital_id_202                                              0
# hospital_id_200                                              0
# hospital_id_20                                               0
# hospital_id_199                                              0
# hospital_id_198                                              0
# apache_3j_diagnosis_desc_unknown                             0

# %%
pipeline_u = load("LGB_U.joblib")
lgb_u = pipeline_u.steps[1][1]
lgb_u_importances = pd.DataFrame({'feature':X_wids.columns,'importance':np.round(lgb_u.feature_importances_,3)})
lgb_u_importances = lgb_u_importances.sort_values('importance',ascending=False).set_index('feature')
lgb_u_importances.head(600)
# Out:
#                                                     importance
# feature
# age                                                         81
# pre_icu_los_days                                            68
# d1_temp_max                                                 47
# d1_heartrate_min                                            42
# d1_spo2_min                                                 41
# d1_resprate_min                                             40
# bmi                                                         40
# d1_glucose_min                                              34
# d1_bun_min                                                  33
# urineoutput_apache                                          33
# weight                                                      32
# d1_wbc_min                                                  31
# d1_heartrate_max                                            31
# d1_arterial_ph_min                                          31
# d1_platelets_min                                            30
# d1_hco3_min                                                 29
# d1_wbc_max                                                  29
# creatinine_apache                                           29
# d1_sodium_max                                               28
# d1_arterial_po2_min                                         28
# d1_arterial_pco2_min                                        28
# eartrate_max_change                                         27
# d1_bun_max                                                  26
# h1_mbp_avg                                                  26
# d1_sysbp_min                                                25
# elective_surgery                                            24
# d1_resprate_max                                             24
# d1_test_total                                               24
# d1_ppv                                                      24
# gcs_score                                                   23
# d1_creatinine_min                                           23
# glucose_apache                                              23
# map_apache                                                  23
# h1_resprate_avg                                             22
# d1_arterial_ph_max                                          22
# d1_temp_min                                                 22
# wbc_apache                                                  21
# ventilated_apache                                           21
# h1_lactate_avg                                              21
# d1_platelets_max                                            20
# d1_mbp_min                                                  20
# d1_arterial_po2_max                                         20
# d1_albumin_min                                              19
# h1_ppv                                                      19
# d1_heartrate_diff                                           19
# heart_rate_apache                                           18
# h1_heartrate_max                                            18
# d1_inr_max                                                  18
# albumin_apache                                              18
# heartrate_med_diff                                          18
# h1_resprate_min                                             17
# spo2_min_change                                             17
# d1_sysbp_noninvasive_min                                    17
# d1_sysbp_max                                                16
# d1_potassium_min                                            16
# d1_bilirubin_max                                            16
# mbp_med_diff                                                16
# bun_apache                                                  16
# d1_temp_diff                                                16
# d1_arterial_pco2_max                                        16
# h1_resprate_max                                             16
# resprate_min_change                                         16
# d1_sysbp_noninvasive_max                                    15
# d1_diasbp_diff                                              15
# h1_inr_avg                                                  15
# apache_3j_bodysystem_Metabolic                              15
# d1_hco3_max                                                 15
# d1_bilirubin_min                                            15
# gcs_motor_apache                                            14
# resprate_apache                                             14
# temp_med_diff                                               14
# apache_3j_diagnosis_desc_Cardiac_arrest                     14
# d1_sysbp_diff                                               14
# d1_calcium_min                                              14
# d1_glucose_diff                                             14
# d1_creatinine_max                                           13
# d1_spo2_diff                                                13
# h1_diasbp_min                                               13
# gcs_unable_apache                                           13
# d1_hemaglobin_min                                           13
# d1_hematocrit_max                                           13
# h1_spo2_avg                                                 13
# d1_potassium_diff                                           13
# d1_hematocrit_diff                                          13
# h1_spo2_min                                                 12
# sysbp_min_change                                            12
# apache_3j_bodysystem_Neurological                           12
# sodium_apache                                               12
# d1_mbp_noninvasive_max                                      12
# mbp_min_change                                              12
# arterial_ph_min_change                                      11
# diasbp_med_diff                                             11
# icu_admit_source_Operating_Room___Recovery                  11
# sysbp_med_diff                                              11
# d1_resprate_diff                                            11
# h1_albumin_avg                                              11
# height                                                      11
# d1_hematocrit_min                                           11
# d1_glucose_max                                              11
# d1_hemaglobin_max                                           11
# d1_diasbp_max                                               11
# d1_calcium_max                                              10
# glucose_med_diff                                            10
# h1_heartrate_avg                                            10
# d1_mbp_max                                                  10
# temp_max_change                                             10
# h1_sysbp_min                                                10
# d1_pao2fio2ratio_diff                                       10
# h1_inr_diff                                                 10
# diasbp_max_change                                           10
# h1_arterial_ph_avg                                          10
# d1_mbp_diff                                                 10
# h1_arterial_po2_avg                                         10
# d1_potassium_max                                            10
# mbp_max_change                                              10
# eartrate_min_change                                         10
# h1_sysbp_diff                                               10
# spo2_med_diff                                                9
# h1_temp_avg                                                  9
# d1_arterial_pco2_diff                                        9
# hematocrit_apache                                            9
# missing_test_total                                           9
# apache_3j_diagnosis_desc_Stroke                              9
# h1_glucose_min                                               9
# temp_apache                                                  9
# resprate_max_change                                          8
# sysbp_max_change                                             8
# h1_resprate_diff                                             8
# h1_sysbp_avg                                                 8
# h1_wbc_avg                                                   8
# h1_diasbp_diff                                               8
# creatinine_min_change                                        8
# solid_tumor_with_metastasis                                  8
# resprate_med_diff                                            8
# h1_pao2fio2ratio_avg                                         7
# h1_diasbp_max                                                7
# h1_mbp_diff                                                  7
# d1_wbc_diff                                                  7
# d1_hemaglobin_diff                                           7
# d1_platelets_diff                                            7
# d1_diasbp_min                                                7
# h1_heartrate_min                                             7
# h1_temp_max                                                  7
# h1_hco3_avg                                                  7
# glucose_max_change                                           7
# d1_mbp_noninvasive_min                                       7
# arterial_ph_med_diff                                         7
# h1_sysbp_max                                                 7
# lactate_med_diff                                             7
# hematocrit_med_diff                                          7
# h1_spo2_max                                                  6
# h1_diasbp_noninvasive_max                                    6
# d1_creatinine_diff                                           6
# d1_lactate_diff                                              6
# d1_hco3_diff                                                 6
# h1_temp_min                                                  6
# d1_sodium_diff                                               6
# h1_heartrate_diff                                            6
# h1_potassium_avg                                             6
# h1_sysbp_noninvasive_max                                     6
# h1_bilirubin_avg                                             6
# hospital_id_76                                               6
# h1_diasbp_avg                                                6
# temp_min_change                                              6
# d1_inr_min                                                   6
# gcs_eyes_apache                                              6
# diasbp_min_change                                            6
# d1_arterial_po2_diff                                         5
# spo2_max_change                                              5
# hospital_id_21                                               5
# creatinine_med_diff                                          5
# h1_bun_avg                                                   5
# bilirubin_apache                                             5
# h1_creatinine_avg                                            5
# d1_albumin_max                                               5
# h1_sodium_avg                                                5
# creatine_risk                                                5
# h1_spo2_diff                                                 5
# apache_3j_diagnosis_desc_Respiratory_neoplasm_i...           5
# gcs_verbal_apache                                            5
# h1_sysbp_noninvasive_min                                     5
# d1_arterial_ph_diff                                          4
# apache_3j_diagnosis_desc_Coronary_artery_bypass...           4
# sodium_min_change                                            4
# h1_mbp_noninvasive_max                                       4
# h1_mbp_min                                                   4
# hospital_id_70                                               4
# h1_calcium_avg                                               4
# diabetes_mellitus                                            4
# h1_glucose_avg                                               4
# arterial_ph_max_change                                       4
# d1_sodium_min                                                4
# apache_3j_bodysystem_Respiratory                             4
# hospital_id_2                                                4
# glucose_min_change                                           4
# apache_post_operative                                        4
# apache_3j_diagnosis_desc_Sepsis__other_than_uri...           4
# d1_bun_diff                                                  4
# d1_calcium_diff                                              4
# emaglobin_min_change                                         4
# lactate_level                                                4
# urine_flag                                                   4
# wbc_level                                                    4
# wbc_min_change                                               4
# ematocrit_min_change                                         3
# hospital_admit_source_Emergency_Department                   3
# bilirubin_risk                                               3
# sodium_med_diff                                              3
# icu_admit_source_Floor                                       3
# potassium_min_change                                         3
# h1_glucose_max                                               3
# platelets_min_change                                         3
# hospital_id_51                                               3
# apache_2_bodysystem_Undefined_diagnoses                      3
# hco3_med_diff                                                3
# h1_diasbp_noninvasive_min                                    3
# apache_3j_bodysystem_Sepsis                                  3
# apache_3j_diagnosis_desc_Drug_overdose                       3
# icu_type_Neuro_ICU                                           3
# icu_type_Med_Surg_ICU                                        3
# h1_glucose_diff                                              3
# apache_3j_diagnosis_desc_Head_trauma_____multi_...           3
# d1_diasbp_noninvasive_min                                    3
# d1_spo2_max                                                  3
# apache_3j_diagnosis_desc_Intracerebral_haemorrhage           3
# h1_arterial_pco2_avg                                         3
# h1_platelets_avg                                             3
# h1_hematocrit_avg                                            3
# h1_hemaglobin_avg                                            3
# h1_mbp_max                                                   3
# icu_admit_source_Other_Hospital                              2
# apache_3j_diagnosis_desc_Laminectomy_Spinal_cor...           2
# icu_type_CCU_CTICU                                           2
# apache_3j_diagnosis_desc_Valvular_heart_surgery              2
# bun_max_change                                               2
# icu_admit_source_Accident___Emergency                        2
# sodium_max_change                                            2
# apache_3j_diagnosis_desc_Aortic_aneurysm                     2
# apache_3j_diagnosis_desc_Multiple_trauma_exclud...           2
# bun_min_change                                               2
# h1_arterial_ph_diff                                          2
# h1_test_total                                                2
# hemaglobin_med_diff                                          2
# cc_total                                                     2
# h1_temp_diff                                                 2
# apache_3j_diagnosis_desc_Other_respiratory_dise...           2
# hospital_admit_source_Operating_Room                         2
# pao2fio2ratio_med_diff                                       2
# wbc_med_diff                                                 2
# arterial_pco2_max_change                                     2
# d1_bilirubin_diff                                            2
# hospital_id_30                                               1
# icu_type_CTICU                                               1
# hospital_id_101                                              1
# apache_3j_diagnosis_desc_Hepatic_failure                     1
# hospital_id_100                                              1
# icu_stay_type_admit                                          1
# icu_type_Cardiac_ICU                                         1
# hospital_id_32                                               1
# icu_type_MICU                                                1
# h1_mbp_noninvasive_min                                       1
# ethnicity_Caucasian                                          1
# apache_3j_bodysystem_Cardiovascular                          1
# apache_3j_diagnosis_desc_GI_bleeding___ulcer_la...           1
# hospital_id_133                                              1
# hospital_id_196                                              1
# hospital_id_81                                               1
# hospital_id_185                                              1
# apache_3j_diagnosis_desc_Bacterial_pneumonia                 1
# hospital_id_18                                               1
# hospital_id_176                                              1
# hospital_id_174                                              1
# d1_diasbp_noninvasive_max                                    1
# apache_3j_diagnosis_desc_Subdural_Epidural_haem...           1
# co3_max_change                                               1
# arterial_po2_max_change                                      1
# hepatic_failure                                              1
# lactate_max_change                                           1
# hospital_admit_source_Floor                                  1
# emaglobin_max_change                                         1
# potassium_med_diff                                           1
# pao2fio2ratio_min_change                                     1
# pao2fio2ratio_max_change                                     1
# co3_min_change                                               1
# hospital_admit_source_Direct_Admit                           1
# hospital_admit_source_unknown                                1
# arterial_pco2_min_change                                     1
# hospital_id_39                                               1
# hospital_id_98                                               0
# apache_3j_bodysystem_unknown                                 0
# apache_3j_bodysystem_Musculoskeletal_Skin                    0
# hospital_id_95                                               0
# hospital_id_94                                               0
# hospital_id_93                                               0
# hospital_admit_source_Other                                  0
# apache_3j_bodysystem_Trauma                                  0
# apache_2_bodysystem_Gastrointestinal                         0
# apache_2_bodysystem_Cardiovascular                           0
# apache_3j_bodysystem_Hematological                           0
# apache_2_bodysystem_Haematologic                             0
# apache_2_bodysystem_Metabolic                                0
# apache_2_bodysystem_Neurologic                               0
# apache_2_bodysystem_Renal_Genitourinary                      0
# hospital_admit_source_Step_Down_Unit__SDU_                   0
# apache_2_bodysystem_Respiratory                              0
# apache_2_bodysystem_Trauma                                   0
# hospital_id_92                                               0
# hospital_admit_source_Recovery_Room                          0
# hospital_admit_source_Other_Hospital                         0
# hospital_id_99                                               0
# hospital_admit_source_Acute_Care_Floor                       0
# apache_3j_bodysystem_Gynecological                           0
# apache_3j_bodysystem_Genitourinary                           0
# gender_M                                                     0
# gender_F                                                     0
# hospital_admit_source_Chest_Pain_Center                      0
# ethnicity_unknown                                            0
# ethnicity_Other_Unknown                                      0
# icu_admit_source_unknown                                     0
# icu_admit_source_Other_ICU                                   0
# icu_stay_type_readmit                                        0
# ethnicity_Native_American                                    0
# hospital_admit_source_Other_ICU                              0
# icu_stay_type_transfer                                       0
# apache_3j_diagnosis_desc_Viral_pneumonia                     0
# ethnicity_Hispanic                                           0
# icu_type_CSICU                                               0
# hospital_admit_source_ICU                                    0
# hospital_admit_source_ICU_to_SDU                             0
# hospital_admit_source_Observation                            0
# apache_2_bodysystem_Undefined_Diagnoses                      0
# ethnicity_Asian                                              0
# icu_type_SICU                                                0
# gender_unknown                                               0
# apache_3j_bodysystem_Gastrointestinal                        0
# ethnicity_African_American                                   0
# hospital_admit_source_PACU                                   0
# apache_3j_diagnosis_desc_GI_vascular_ischaemia_...           0
# apache_2_bodysystem_unknown                                  0
# apache_3j_diagnosis_desc_Sepsis_of_urinary_trac...           0
# apache_3j_diagnosis_desc_Other_gynaecological_d...           0
# apache_3j_diagnosis_desc_Other_cardiovascular_d...           0
# apache_3j_diagnosis_desc_Other_cardiovascular_d...           0
# apache_3j_diagnosis_desc_Other_GI_inflammatory_...           0
# apache_3j_diagnosis_desc_Aspiration_pneumonia                0
# apache_3j_diagnosis_desc_Aorto_femoral_bypass_g...           0
# apache_3j_diagnosis_desc_Dissecting_aortic_aneu...           0
# apache_3j_diagnosis_desc_Epidural_haematoma                  0
# apache_3j_diagnosis_desc_Kidney_transplant                   0
# apache_3j_diagnosis_desc_Fistula_Abscess_surgery             0
# apache_3j_diagnosis_desc_Isolated_cervical_spin...           0
# apache_3j_diagnosis_desc_Isolated_cervical_spin...           0
# apache_3j_diagnosis_desc_Hysterectomy                        0
# apache_3j_diagnosis_desc_Hypertension                        0
# apache_3j_diagnosis_desc_Haemorrhage__post_part...           0
# apache_3j_diagnosis_desc_Haematological_disease              0
# apache_3j_diagnosis_desc_Genitourinary_surgery_...           0
# apache_3j_diagnosis_desc_Peripheral_artery_bypa...           0
# apache_3j_diagnosis_desc_GI_vascular_insufficiency           0
# apache_3j_diagnosis_desc_GI_perforation_rupture...           0
# apache_3j_diagnosis_desc_GI_perforation                      0
# apache_3j_diagnosis_desc_GI_obstruction                      0
# apache_3j_diagnosis_desc_GI_neoplasm                         0
# apache_3j_diagnosis_desc_GI_cancer                           0
# apache_3j_diagnosis_desc_GI_bleeding___varices               0
# apache_3j_diagnosis_desc_GI_bleeding___divertic...           0
# apache_3j_diagnosis_desc_GI_bleeding                         0
# hospital_id_91                                               0
# hospital_id_119                                              0
# hospital_id_9                                                0
# hospital_id_10                                               0
# hospital_id_112                                              0
# hospital_id_111                                              0
# hospital_id_109                                              0
# hospital_id_107                                              0
# hospital_id_105                                              0
# hospital_id_104                                              0
# hospital_id_103                                              0
# hospital_id_102                                              0
# wbc_max_change                                               0
# hospital_id_116                                              0
# potassium_max_change                                         0
# platelets_max_change                                         0
# lactate_min_change                                           0
# inr_min_change                                               0
# inr_max_change                                               0
# ematocrit_max_change                                         0
# creatinine_max_change                                        0
# calcium_min_change                                           0
# hospital_id_113                                              0
# hospital_id_117                                              0
# bilirubin_min_change                                         0
# hospital_id_135                                              0
# hospital_id_145                                              0
# hospital_id_142                                              0
# hospital_id_140                                              0
# hospital_id_14                                               0
# hospital_id_139                                              0
# hospital_id_138                                              0
# hospital_id_137                                              0
# hospital_id_136                                              0
# hospital_id_134                                              0
# hospital_id_118                                              0
# hospital_id_132                                              0
# hospital_id_130                                              0
# hospital_id_13                                               0
# hospital_id_129                                              0
# hospital_id_128                                              0
# hospital_id_125                                              0
# hospital_id_124                                              0
# hospital_id_121                                              0
# calcium_max_change                                           0
# bilirubin_max_change                                         0
# hospital_id_147                                              0
# lymphoma                                                     0
# h1_hemaglobin_diff                                           0
# h1_hco3_diff                                                 0
# h1_creatinine_diff                                           0
# h1_calcium_diff                                              0
# h1_bun_diff                                                  0
# h1_bilirubin_diff                                            0
# h1_albumin_diff                                              0
# glucose_risk                                                 0
# leukemia                                                     0
# h1_lactate_diff                                              0
# immunosuppression                                            0
# cirrhosis                                                    0
# aids                                                         0
# h1_inr_min                                                   0
# h1_inr_max                                                   0
# intubated_apache                                             0
# arf_apache                                                   0
# readmission_status                                           0
# h1_hematocrit_diff                                           0
