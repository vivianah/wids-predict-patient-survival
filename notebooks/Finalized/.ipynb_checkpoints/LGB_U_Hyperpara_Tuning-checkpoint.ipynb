# %%
# importing standard packages
import pandas as pd
import numpy as np 
from scipy import stats 

# importing the plot funnctions
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 

# preprocessing/ model selection 
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score

# importing the classifiers 
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

# importing the metrics 
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, classification_report,f1_score
from sklearn.metrics import roc_curve

# oversampling techniques 
from imblearn.over_sampling import SMOTE

# importing model saving package 
from joblib import dump, load

from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline, make_pipeline
# Out:
# /anaconda3/lib/python3.6/site-packages/dask/dataframe/utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Functions

# %%
def draw_conf_mat(mat):
    
    """
    Draw confusion matrix
    
    Parameters:
    ------------------
    mat:                ndarray of shape (n_classes, n_classes) 
                        confusion matrix

    """
    
    import matplotlib.pyplot as plt 
    import seaborn as sns
    
    fig, ax = plt.subplots(figsize=(8, 8))
    sns.heatmap(mat, annot=True, fmt="d",
            xticklabels=['0', '1'],
            yticklabels=['0', '1'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    ax.set_ylim([0,2])
    ax.invert_yaxis()
    plt.show()
    
    return ax

# %%
# grab the stored data frames
# %store -r X_wids
# %store -r y_wids

# %%
X_wids = X_wids.drop(columns= ['hospital_admit_source_Observation'])

# %%
X_wids.shape, y_wids.shape
# Out:
# ((91713, 597), (91713, 1))

# %% [markdown]
# ## Train Test Split without Correction of Imbalanced Data

# %%
# Split train-test dataset 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_wids, y_wids, test_size = 0.2, random_state = 31, stratify = y_wids)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (73370, 597) (18343, 597) (73370, 1) (18343, 1)

# %% [markdown]
# # RandomSearch

# %%
# Load the pipeline of LGB_U
LGB_U_pipeline = load('LGB_U.joblib')

# %%
# Set parameters we want to search
lgb_params = {'num_leaves': [20,31, 50, 60, 90],
              'learning_rate': [.01,.05,1.0],
            'n_estimators': [100,150,200,250],
            'min_data_in_leaf':[50,100,200],
             'max_depth': [7, 10, -1]}

# %%
# Change lgb_params to pipeline format
new_params = {'lgbmclassifier__' + key: lgb_params[key] for key in lgb_params}

# %%
rnd_search = RandomizedSearchCV(LGB_U_pipeline, param_distributions=new_params, cv=4, n_iter=11, scoring='recall',
                        return_train_score=True)
rnd_search.fit(X_train.values, y_train.values.ravel())
# Out:
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# RandomizedSearchCV(cv=4, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('randomundersampler',
#                                               RandomUnderSampler(random_state=42,
#                                                                  ratio=None,
#                                                                  replacement=False,
#                                                                  return_indices=False,
#                                                                  sampling_strategy=1)),
#                                              ('lgbmclassifier',
#                                               LGBMClassifier(booster='gbtree',
#                                                              boosting_type='gbdt',
#                                                              class_weight=None,
#                                                              colsample_bytree=1.0,
#                                                              importance_type='split',
#                                                              learning_...
#                    param_distributions={'lgbmclassifier__learning_rate': [0.01,
#                                                                           0.05,
#                                                                           1.0],
#                                         'lgbmclassifier__max_depth': [7, 10,
#                                                                       -1],
#                                         'lgbmclassifier__min_data_in_leaf': [50,
#                                                                              100,
#                                                                              200],
#                                         'lgbmclassifier__n_estimators': [100,
#                                                                          150,
#                                                                          200,
#                                                                          250],
#                                         'lgbmclassifier__num_leaves': [20, 31,
#                                                                        50, 60,
#                                                                        90]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
rnd_search.best_params_
# Out:
# {'lgbmclassifier__num_leaves': 90,
#  'lgbmclassifier__n_estimators': 250,
#  'lgbmclassifier__min_data_in_leaf': 50,
#  'lgbmclassifier__max_depth': 10,
#  'lgbmclassifier__learning_rate': 0.05}

# %% [markdown]
# # Evaluate

# %%
# Build the model with our best parameters
lgb_best = LGBMClassifier(booster ='gbtree', n_estimators = 250, learning_rate = .05, 
                          max_depth = 10, num_leaves=90, min_data_in_leaf=50, objective ='binary')

# Make undersampling
rus = RandomUnderSampler(sampling_strategy = 1, random_state=42)
lgb_rus_pipeline = make_pipeline(rus,lgb_best)

# %%
result_matrix = pd.DataFrame(columns = ['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV'])
# fit model
lgb_rus_pipeline.fit(X_train.values, y_train.values.ravel())

# prediction of y based on X_test
y_predict = lgb_rus_pipeline.predict(X_test.values)
    
# prediction of y probability based on X_test
y_proba = lgb_rus_pipeline.predict_proba(X_test.values)[:,1]

# prediction of y based on X_train
y_train_predict = lgb_rus_pipeline.predict(X_train.values)

cmat = confusion_matrix(y_test.values.ravel(), y_predict)
# tp, fn, fp, tn
tp = cmat[1,1]
fn = cmat[1,0]
fp = cmat[0,1]
tn = cmat[0,0]

#precision score on test
p_score_test = precision_score(y_test.values.ravel(), y_predict)

#recall score on test
r_score_test = tp/(tp+fn) 

#FPR score on test
fpr_test = fp/(fp+tn)

#AUROC score on test
auroc_test = roc_auc_score(y_test.values.ravel(), y_proba)

#f1 score on test
f1_test = f1_score(y_test.values.ravel(), y_predict)

#f1 score on train
f1_train = f1_score(y_train.values.ravel(), y_train_predict)

#f1 score on cross validation 
k_fold = 4
f1_cv = cross_val_score(lgb_rus_pipeline, X_train, y_train.values.ravel(), cv=k_fold, scoring = 'f1')
recall_cv = cross_val_score(lgb_rus_pipeline, X_train.values, y_train.values.ravel(), 
                            cv=k_fold, scoring = 'recall')
print(f"Cross Validation is on {k_fold} folds.")

# append to matrix
df2 = pd.DataFrame([['LGB_U_tuned',p_score_test,r_score_test, fpr_test, auroc_test, f1_test, f1_train, f1_cv, recall_cv]], 
                       columns=['model', 'precision_test', 'recall_test', 'FPR_test', 'AUROC_test',
                                     'f1_test', 'f1_train', 'f1_CV', 'recall_CV'])
    
result_matrix = pd.concat([df2, result_matrix])
# Out:
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Cross Validation is on 4 folds.

# %%
result_matrix.explode('f1_CV')
# Out:
#          model  precision_test  recall_test  FPR_test  AUROC_test   f1_test  \
# 0  LGB_U_tuned        0.290438     0.821226  0.189499    0.898039  0.429114
# 0  LGB_U_tuned        0.290438     0.821226  0.189499    0.898039  0.429114
# 0  LGB_U_tuned        0.290438     0.821226  0.189499    0.898039  0.429114
# 0  LGB_U_tuned        0.290438     0.821226  0.189499    0.898039  0.429114
#
#    f1_train     f1_CV                                          recall_CV
# 0  0.512608  0.415793  [0.8016424510423247, 0.8294377763739734, 0.814...
# 0  0.512608   0.43891  [0.8016424510423247, 0.8294377763739734, 0.814...
# 0  0.512608  0.421586  [0.8016424510423247, 0.8294377763739734, 0.814...
# 0  0.512608  0.418756  [0.8016424510423247, 0.8294377763739734, 0.814...

# %%
# We are fine with this result. CV score and train score are different by 10%. We will accept this for now. 

# save model
dump(lgb_rus_pipeline, 'LGB_u_best.joblib')
# Out:
# ['LGB_u_best.joblib']

# %%
# Draw confusion matrix
draw_conf_mat(cmat)

# %% [markdown]
# # Feature importance

# %%
lgb_rus_pipeline = load('LGB_u_best.joblib')

# %%
feat_important = pd.DataFrame({'feature': X_train.columns, 
                               'importance': lgb_rus_pipeline.steps[1][1].feature_importances_})

# %%
feat_important = feat_important.sort_values('importance', ascending=False)

# %%
# Plot feature importance
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()
ax.barh(feat_important['feature'][:20], feat_important['importance'][:20], align='center')
ax.set_yticks(feat_important['feature'][:20])
ax.invert_yaxis() 
ax.set_xlabel('importance score')
ax.set_title('Feature Importance Score')

plt.tight_layout()
fig.savefig('feature_importance.png')

# %% [markdown]
# # Submit to Kaggle

# %% [markdown]
# ### 1. submit using undersampled model

# %%
# %store -r X_wids_holdout

# %%
X_wids_holdout
# Out:
#             encounter_id   age        bmi  elective_surgery  height  \
# patient_id
# 127112                 2  56.0  21.102439                 0   180.3
# 130737                 5  63.0  19.500595                 1   145.0
# 101458                 7  66.0  32.518596                 1   170.2
# 48067                  8  64.0  20.798520                 0   182.8
# 25865                 10  56.0  27.412446                 0   170.0
# ...                  ...   ...        ...               ...     ...
# 12233             131035  35.0  35.038615                 1   170.2
# 56614             131037  63.0  29.352338                 0   175.3
# 106611            131039  71.0  23.010381                 0   170.0
# 18175             131041  57.0  32.987948                 0   185.4
# 72213             131050  66.0  23.183391                 0   170.0
#
#             pre_icu_los_days  readmission_status  weight  albumin_apache  \
# patient_id
# 127112              0.104167                   0   68.60             3.7
# 130737              0.230556                   0   41.00             3.0
# 101458              0.140972                   0   94.20             3.0
# 48067               0.002083                   0   69.50             1.9
# 25865               0.004861                   0   66.40             2.6
# ...                      ...                 ...     ...             ...
# 12233               0.411111                   0  101.50             3.0
# 56614               0.218056                   0   90.20             3.0
# 106611              0.003472                   0   66.50             2.0
# 18175               0.147917                   0  113.39             3.0
# 72213               4.738194                   0   67.00             2.7
#
#             apache_post_operative  ...  \
# patient_id                         ...
# 127112                          0  ...
# 130737                          1  ...
# 101458                          1  ...
# 48067                           0  ...
# 25865                           1  ...
# ...                           ...  ...
# 12233                           1  ...
# 56614                           0  ...
# 106611                          0  ...
# 18175                           0  ...
# 72213                           0  ...
#
#             apache_3j_diagnosis_desc_Sepsis__other_than_urinary  \
# patient_id
# 127112                                                      0
# 130737                                                      0
# 101458                                                      0
# 48067                                                       0
# 25865                                                       0
# ...                                                       ...
# 12233                                                       0
# 56614                                                       0
# 106611                                                      0
# 18175                                                       0
# 72213                                                       0
#
#             apache_3j_diagnosis_desc_Sepsis_of_urinary_tract_origin  \
# patient_id
# 127112                                                      0
# 130737                                                      0
# 101458                                                      0
# 48067                                                       0
# 25865                                                       0
# ...                                                       ...
# 12233                                                       0
# 56614                                                       0
# 106611                                                      1
# 18175                                                       0
# 72213                                                       0
#
#             apache_3j_diagnosis_desc_Skin_surgery  \
# patient_id
# 127112                                          0
# 130737                                          0
# 101458                                          0
# 48067                                           0
# 25865                                           0
# ...                                           ...
# 12233                                           0
# 56614                                           0
# 106611                                          0
# 18175                                           0
# 72213                                           0
#
#             apache_3j_diagnosis_desc_Stroke  \
# patient_id
# 127112                                    0
# 130737                                    0
# 101458                                    0
# 48067                                     0
# 25865                                     0
# ...                                     ...
# 12233                                     0
# 56614                                     0
# 106611                                    0
# 18175                                     0
# 72213                                     0
#
#             apache_3j_diagnosis_desc_Subarachnoid_haemorrhage  \
# patient_id
# 127112                                                      0
# 130737                                                      0
# 101458                                                      0
# 48067                                                       0
# 25865                                                       0
# ...                                                       ...
# 12233                                                       0
# 56614                                                       0
# 106611                                                      0
# 18175                                                       0
# 72213                                                       0
#
#             apache_3j_diagnosis_desc_Subdural_Epidural_haematoma  \
# patient_id
# 127112                                                      0
# 130737                                                      1
# 101458                                                      0
# 48067                                                       0
# 25865                                                       0
# ...                                                       ...
# 12233                                                       0
# 56614                                                       0
# 106611                                                      0
# 18175                                                       0
# 72213                                                       0
#
#             apache_3j_diagnosis_desc_Unstable_angina  \
# patient_id
# 127112                                             0
# 130737                                             0
# 101458                                             0
# 48067                                              0
# 25865                                              0
# ...                                              ...
# 12233                                              0
# 56614                                              0
# 106611                                             0
# 18175                                              0
# 72213                                              0
#
#             apache_3j_diagnosis_desc_Valvular_heart_surgery  \
# patient_id
# 127112                                                    0
# 130737                                                    0
# 101458                                                    0
# 48067                                                     0
# 25865                                                     0
# ...                                                     ...
# 12233                                                     0
# 56614                                                     0
# 106611                                                    0
# 18175                                                     0
# 72213                                                     0
#
#             apache_3j_diagnosis_desc_Viral_pneumonia  \
# patient_id
# 127112                                             0
# 130737                                             0
# 101458                                             0
# 48067                                              0
# 25865                                              0
# ...                                              ...
# 12233                                              0
# 56614                                              0
# 106611                                             0
# 18175                                              0
# 72213                                              0
#
#             apache_3j_diagnosis_desc_unknown
# patient_id
# 127112                                     0
# 130737                                     0
# 101458                                     0
# 48067                                      0
# 25865                                      0
# ...                                      ...
# 12233                                      0
# 56614                                      0
# 106611                                     0
# 18175                                      0
# 72213                                      0
#
# [39308 rows x 453 columns]

# %%
encounter_id = X_wids_holdout['encounter_id']

# %%
# Check the columns match between X_train and X_wids
list(set(X_train) - set(X_wids_holdout))
# Out:
# ['hospital_id_200',
#  'hospital_id_198',
#  'hospital_id_180',
#  'hospital_id_81',
#  'hospital_id_146',
#  'hospital_id_187',
#  'hospital_id_186',
#  'hospital_id_176',
#  'hospital_id_54',
#  'hospital_id_197',
#  'hospital_id_111',
#  'hospital_id_30',
#  'hospital_id_68',
#  'hospital_id_204',
#  'hospital_id_192',
#  'hospital_id_166',
#  'hospital_id_125',
#  'hospital_id_134',
#  'hospital_id_17',
#  'hospital_id_119',
#  'hospital_id_188',
#  'hospital_id_2',
#  'hospital_id_184',
#  'hospital_id_57',
#  'hospital_id_105',
#  'hospital_id_5',
#  'hospital_id_69',
#  'hospital_id_179',
#  'hospital_id_157',
#  'hospital_id_46',
#  'hospital_id_87',
#  'hospital_id_77',
#  'hospital_id_94',
#  'hospital_id_3',
#  'hospital_id_151',
#  'hospital_id_194',
#  'hospital_id_36',
#  'hospital_id_19',
#  'hospital_id_183',
#  'hospital_id_133',
#  'hospital_id_171',
#  'hospital_id_14',
#  'hospital_id_20',
#  'hospital_id_63',
#  'hospital_id_136',
#  'hospital_id_34',
#  'hospital_id_74',
#  'hospital_id_39',
#  'hospital_id_181',
#  'hospital_id_35',
#  'hospital_id_196',
#  'hospital_id_24',
#  'hospital_id_195',
#  'hospital_id_8',
#  'hospital_id_32',
#  'hospital_id_53',
#  'hospital_id_79',
#  'hospital_id_135',
#  'hospital_id_55',
#  'hospital_id_15',
#  'hospital_id_27',
#  'hospital_id_37',
#  'hospital_id_60',
#  'hospital_id_137',
#  'hospital_id_150',
#  'hospital_id_113',
#  'hospital_id_147',
#  'hospital_id_93',
#  'hospital_id_98',
#  'hospital_id_128',
#  'hospital_id_84',
#  'hospital_id_149',
#  'hospital_id_49',
#  'hospital_id_70',
#  'hospital_id_129',
#  'hospital_id_132',
#  'hospital_id_107',
#  'hospital_id_100',
#  'hospital_id_91',
#  'hospital_id_189',
#  'hospital_id_182',
#  'hospital_id_159',
#  'hospital_id_16',
#  'hospital_id_64',
#  'hospital_id_6',
#  'hospital_id_80',
#  'hospital_id_78',
#  'hospital_id_130',
#  'hospital_id_169',
#  'hospital_id_13',
#  'hospital_id_23',
#  'hospital_id_112',
#  'hospital_id_116',
#  'hospital_id_174',
#  'hospital_id_38',
#  'hospital_id_76',
#  'hospital_id_40',
#  'hospital_id_167',
#  'hospital_id_26',
#  'hospital_id_109',
#  'hospital_id_139',
#  'hospital_id_90',
#  'hospital_id_33',
#  'hospital_id_101',
#  'hospital_id_83',
#  'hospital_id_104',
#  'hospital_id_92',
#  'hospital_id_177',
#  'hospital_id_71',
#  'hospital_id_155',
#  'hospital_id_103',
#  'hospital_id_72',
#  'hospital_id_43',
#  'hospital_id_10',
#  'hospital_id_140',
#  'hospital_id_62',
#  'hospital_id_95',
#  'hospital_id_51',
#  'hospital_id_21',
#  'hospital_id_161',
#  'hospital_id_158',
#  'hospital_id_102',
#  'hospital_id_4',
#  'hospital_id_18',
#  'hospital_id_117',
#  'hospital_id_85',
#  'hospital_id_47',
#  'hospital_id_31',
#  'hospital_id_168',
#  'hospital_id_202',
#  'hospital_id_124',
#  'hospital_id_121',
#  'hospital_id_118',
#  'hospital_id_29',
#  'hospital_id_9',
#  'hospital_id_142',
#  'hospital_id_50',
#  'hospital_id_89',
#  'hospital_id_185',
#  'hospital_id_88',
#  'hospital_id_160',
#  'hospital_id_145',
#  'hospital_id_99',
#  'hospital_id_199',
#  'hospital_id_66',
#  'hospital_id_44',
#  'hospital_id_138']

# %%
list(set(X_wids_holdout) - set(X_train))
# Out:
# ['encounter_id', 'apache_4a_hospital_death_prob', 'apache_4a_icu_death_prob']

# %%
# Drop extra columns from X_wids_holdout
X_wids_holdout.drop(['encounter_id', 'apache_4a_hospital_death_prob', 
                     'apache_4a_icu_death_prob'], axis=1, inplace=True)

# %%
# Drop extra from X_train
X_train.drop(list(set(X_train) - set(X_wids_holdout)), axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Re-train the model
# Build the model with our best parameters
lgb_best = LGBMClassifier(booster ='gbtree', n_estimators = 250, learning_rate = .05, 
                          max_depth = 10, num_leaves=90, min_data_in_leaf=50, objective ='binary')

# Make undersampling
rus = RandomUnderSampler(sampling_strategy = 1, random_state=42)
lgb_rus_pipeline = make_pipeline(rus,lgb_best)

# Fit to the data
lgb_rus_pipeline.fit(X_train.values, y_train.values.ravel())
# Out:
# /Users/Jenny/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(memory=None,
#          steps=[('randomundersampler',
#                  RandomUnderSampler(random_state=42, ratio=None,
#                                     replacement=False, return_indices=False,
#                                     sampling_strategy=1)),
#                 ('lgbmclassifier',
#                  LGBMClassifier(booster='gbtree', boosting_type='gbdt',
#                                 class_weight=None, colsample_bytree=1.0,
#                                 importance_type='split', learning_rate=0.05,
#                                 max_depth=10, min_child_samples=20,
#                                 min_child_weight=0.001, min_data_in_leaf=50,
#                                 min_split_gain=0.0, n_estimators=250, n_jobs=-1,
#                                 num_leaves=90, objective='binary',
#                                 random_state=None, reg_alpha=0.0,
#                                 reg_lambda=0.0, silent=True, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %%
prediction = lgb_rus_pipeline.predict_proba(X_wids_holdout)

# %%
submission = pd.DataFrame({'encounter_id': np.array(encounter_id), 'hospital_death': prediction[:,1]})

# %%
submission
# Out:
#        encounter_id  hospital_death
# 0                 2        0.151098
# 1                 5        0.117401
# 2                 7        0.206137
# 3                 8        0.603434
# 4                10        0.932714
# ...             ...             ...
# 39303        131035        0.012872
# 39304        131037        0.118709
# 39305        131039        0.649388
# 39306        131041        0.092570
# 39307        131050        0.824217
#
# [39308 rows x 2 columns]

# %%
submission.to_csv("uchicago_submission3.csv", index = False)

# %%
pd.read_csv('uchicago_submission3.csv')
# Out:
#        encounter_id  hospital_death
# 0                 2        0.151098
# 1                 5        0.117401
# 2                 7        0.206137
# 3                 8        0.603434
# 4                10        0.932714
# ...             ...             ...
# 39303        131035        0.012872
# 39304        131037        0.118709
# 39305        131039        0.649388
# 39306        131041        0.092570
# 39307        131050        0.824217
#
# [39308 rows x 2 columns]
